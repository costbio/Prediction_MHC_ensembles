# %% [markdown]
# # Pep Free

# %%
import sys
sys.path.append("../..")

from data.training_simulations import save_training_xtcs

conditions = [
    "shuffle_allframes",
    "shuffle_not_allframes",
    "not_shuffle_allframes",
    "not_shuffle_not_allframes"
]

for condition in conditions:
    save_training_xtcs(
        protein_id="pep_free",
        condition=condition,
        replicas=(0, 1, 2),
        fractions=(10, 20, 30, 40, 50, 60, 70),
        base_data_dir="../../data/palantir_data",
        output_dir="Training_XTCs",
        seed=42
    )
# Out:
# === pep_free | rep 0 | shuffle_allframes ===
# Original frames: 5001
# [Fraction 10] Seed: 52 | Train frames: 500 | Saved: Training_XTCs/shuffle_allframes/pep_free/pep_free_rep_0/fraction_10/training_pep_free_rep_0_frac_10.xtc
# [Fraction 20] Seed: 62 | Train frames: 1000 | Saved: Training_XTCs/shuffle_allframes/pep_free/pep_free_rep_0/fraction_20/training_pep_free_rep_0_frac_20.xtc
# [Fraction 30] Seed: 72 | Train frames: 1500 | Saved: Training_XTCs/shuffle_allframes/pep_free/pep_free_rep_0/fraction_30/training_pep_free_rep_0_frac_30.xtc
# [Fraction 40] Seed: 82 | Train frames: 2000 | Saved: Training_XTCs/shuffle_allframes/pep_free/pep_free_rep_0/fraction_40/training_pep_free_rep_0_frac_40.xtc
# [Fraction 50] Seed: 92 | Train frames: 2500 | Saved: Training_XTCs/shuffle_allframes/pep_free/pep_free_rep_0/fraction_50/training_pep_free_rep_0_frac_50.xtc
# [Fraction 60] Seed: 102 | Train frames: 3000 | Saved: Training_XTCs/shuffle_allframes/pep_free/pep_free_rep_0/fraction_60/training_pep_free_rep_0_frac_60.xtc
# [Fraction 70] Seed: 112 | Train frames: 3500 | Saved: Training_XTCs/shuffle_allframes/pep_free/pep_free_rep_0/fraction_70/training_pep_free_rep_0_frac_70.xtc
#
# === pep_free | rep 1 | shuffle_allframes ===
# Original frames: 5001
# [Fraction 10] Seed: 52 | Train frames: 500 | Saved: Training_XTCs/shuffle_allframes/pep_free/pep_free_rep_1/fraction_10/training_pep_free_rep_1_frac_10.xtc
# [Fraction 20] Seed: 62 | Train frames: 1000 | Saved: Training_XTCs/shuffle_allframes/pep_free/pep_free_rep_1/fraction_20/training_pep_free_rep_1_frac_20.xtc
# [Fraction 30] Seed: 72 | Train frames: 1500 | Saved: Training_XTCs/shuffle_allframes/pep_free/pep_free_rep_1/fraction_30/training_pep_free_rep_1_frac_30.xtc
# [Fraction 40] Seed: 82 | Train frames: 2000 | Saved: Training_XTCs/shuffle_allframes/pep_free/pep_free_rep_1/fraction_40/training_pep_free_rep_1_frac_40.xtc
# [Fraction 50] Seed: 92 | Train frames: 2500 | Saved: Training_XTCs/shuffle_allframes/pep_free/pep_free_rep_1/fraction_50/training_pep_free_rep_1_frac_50.xtc
# [Fraction 60] Seed: 102 | Train frames: 3000 | Saved: Training_XTCs/shuffle_allframes/pep_free/pep_free_rep_1/fraction_60/training_pep_free_rep_1_frac_60.xtc
# [Fraction 70] Seed: 112 | Train frames: 3500 | Saved: Training_XTCs/shuffle_allframes/pep_free/pep_free_rep_1/fraction_70/training_pep_free_rep_1_frac_70.xtc
#
# === pep_free | rep 2 | shuffle_allframes ===
# Original frames: 5001
# [Fraction 10] Seed: 52 | Train frames: 500 | Saved: Training_XTCs/shuffle_allframes/pep_free/pep_free_rep_2/fraction_10/training_pep_free_rep_2_frac_10.xtc
# [Fraction 20] Seed: 62 | Train frames: 1000 | Saved: Training_XTCs/shuffle_allframes/pep_free/pep_free_rep_2/fraction_20/training_pep_free_rep_2_frac_20.xtc
# [Fraction 30] Seed: 72 | Train frames: 1500 | Saved: Training_XTCs/shuffle_allframes/pep_free/pep_free_rep_2/fraction_30/training_pep_free_rep_2_frac_30.xtc
# [Fraction 40] Seed: 82 | Train frames: 2000 | Saved: Training_XTCs/shuffle_allframes/pep_free/pep_free_rep_2/fraction_40/training_pep_free_rep_2_frac_40.xtc
# [Fraction 50] Seed: 92 | Train frames: 2500 | Saved: Training_XTCs/shuffle_allframes/pep_free/pep_free_rep_2/fraction_50/training_pep_free_rep_2_frac_50.xtc
# [Fraction 60] Seed: 102 | Train frames: 3000 | Saved: Training_XTCs/shuffle_allframes/pep_free/pep_free_rep_2/fraction_60/training_pep_free_rep_2_frac_60.xtc
# [Fraction 70] Seed: 112 | Train frames: 3500 | Saved: Training_XTCs/shuffle_allframes/pep_free/pep_free_rep_2/fraction_70/training_pep_free_rep_2_frac_70.xtc
#
# === pep_free | rep 0 | shuffle_not_allframes ===
# Original frames: 5001
# [Fraction 10] Seed: 52 | Train frames: 485 | Saved: Training_XTCs/shuffle_not_allframes/pep_free/pep_free_rep_0/fraction_10/training_pep_free_rep_0_frac_10.xtc
# [Fraction 20] Seed: 62 | Train frames: 970 | Saved: Training_XTCs/shuffle_not_allframes/pep_free/pep_free_rep_0/fraction_20/training_pep_free_rep_0_frac_20.xtc
# [Fraction 30] Seed: 72 | Train frames: 1455 | Saved: Training_XTCs/shuffle_not_allframes/pep_free/pep_free_rep_0/fraction_30/training_pep_free_rep_0_frac_30.xtc
# [Fraction 40] Seed: 82 | Train frames: 1940 | Saved: Training_XTCs/shuffle_not_allframes/pep_free/pep_free_rep_0/fraction_40/training_pep_free_rep_0_frac_40.xtc
# [Fraction 50] Seed: 92 | Train frames: 2425 | Saved: Training_XTCs/shuffle_not_allframes/pep_free/pep_free_rep_0/fraction_50/training_pep_free_rep_0_frac_50.xtc
# [Fraction 60] Seed: 102 | Train frames: 2910 | Saved: Training_XTCs/shuffle_not_allframes/pep_free/pep_free_rep_0/fraction_60/training_pep_free_rep_0_frac_60.xtc
# [Fraction 70] Seed: 112 | Train frames: 3395 | Saved: Training_XTCs/shuffle_not_allframes/pep_free/pep_free_rep_0/fraction_70/training_pep_free_rep_0_frac_70.xtc
#
# === pep_free | rep 1 | shuffle_not_allframes ===
# Original frames: 5001
# [Fraction 10] Seed: 52 | Train frames: 485 | Saved: Training_XTCs/shuffle_not_allframes/pep_free/pep_free_rep_1/fraction_10/training_pep_free_rep_1_frac_10.xtc
# [Fraction 20] Seed: 62 | Train frames: 970 | Saved: Training_XTCs/shuffle_not_allframes/pep_free/pep_free_rep_1/fraction_20/training_pep_free_rep_1_frac_20.xtc
# [Fraction 30] Seed: 72 | Train frames: 1455 | Saved: Training_XTCs/shuffle_not_allframes/pep_free/pep_free_rep_1/fraction_30/training_pep_free_rep_1_frac_30.xtc
# [Fraction 40] Seed: 82 | Train frames: 1940 | Saved: Training_XTCs/shuffle_not_allframes/pep_free/pep_free_rep_1/fraction_40/training_pep_free_rep_1_frac_40.xtc
# [Fraction 50] Seed: 92 | Train frames: 2425 | Saved: Training_XTCs/shuffle_not_allframes/pep_free/pep_free_rep_1/fraction_50/training_pep_free_rep_1_frac_50.xtc
# [Fraction 60] Seed: 102 | Train frames: 2910 | Saved: Training_XTCs/shuffle_not_allframes/pep_free/pep_free_rep_1/fraction_60/training_pep_free_rep_1_frac_60.xtc
# [Fraction 70] Seed: 112 | Train frames: 3395 | Saved: Training_XTCs/shuffle_not_allframes/pep_free/pep_free_rep_1/fraction_70/training_pep_free_rep_1_frac_70.xtc
#
# === pep_free | rep 2 | shuffle_not_allframes ===
# Original frames: 5001
# [Fraction 10] Seed: 52 | Train frames: 485 | Saved: Training_XTCs/shuffle_not_allframes/pep_free/pep_free_rep_2/fraction_10/training_pep_free_rep_2_frac_10.xtc
# [Fraction 20] Seed: 62 | Train frames: 970 | Saved: Training_XTCs/shuffle_not_allframes/pep_free/pep_free_rep_2/fraction_20/training_pep_free_rep_2_frac_20.xtc
# [Fraction 30] Seed: 72 | Train frames: 1455 | Saved: Training_XTCs/shuffle_not_allframes/pep_free/pep_free_rep_2/fraction_30/training_pep_free_rep_2_frac_30.xtc
# [Fraction 40] Seed: 82 | Train frames: 1940 | Saved: Training_XTCs/shuffle_not_allframes/pep_free/pep_free_rep_2/fraction_40/training_pep_free_rep_2_frac_40.xtc
# [Fraction 50] Seed: 92 | Train frames: 2425 | Saved: Training_XTCs/shuffle_not_allframes/pep_free/pep_free_rep_2/fraction_50/training_pep_free_rep_2_frac_50.xtc
# [Fraction 60] Seed: 102 | Train frames: 2910 | Saved: Training_XTCs/shuffle_not_allframes/pep_free/pep_free_rep_2/fraction_60/training_pep_free_rep_2_frac_60.xtc
# [Fraction 70] Seed: 112 | Train frames: 3395 | Saved: Training_XTCs/shuffle_not_allframes/pep_free/pep_free_rep_2/fraction_70/training_pep_free_rep_2_frac_70.xtc
#
# === pep_free | rep 0 | not_shuffle_allframes ===
# Original frames: 5001
# [Fraction 10] Seed: 52 | Train frames: 500 | Saved: Training_XTCs/not_shuffle_allframes/pep_free/pep_free_rep_0/fraction_10/training_pep_free_rep_0_frac_10.xtc
# [Fraction 20] Seed: 62 | Train frames: 1000 | Saved: Training_XTCs/not_shuffle_allframes/pep_free/pep_free_rep_0/fraction_20/training_pep_free_rep_0_frac_20.xtc
# [Fraction 30] Seed: 72 | Train frames: 1500 | Saved: Training_XTCs/not_shuffle_allframes/pep_free/pep_free_rep_0/fraction_30/training_pep_free_rep_0_frac_30.xtc
# [Fraction 40] Seed: 82 | Train frames: 2000 | Saved: Training_XTCs/not_shuffle_allframes/pep_free/pep_free_rep_0/fraction_40/training_pep_free_rep_0_frac_40.xtc
# [Fraction 50] Seed: 92 | Train frames: 2500 | Saved: Training_XTCs/not_shuffle_allframes/pep_free/pep_free_rep_0/fraction_50/training_pep_free_rep_0_frac_50.xtc
# [Fraction 60] Seed: 102 | Train frames: 3000 | Saved: Training_XTCs/not_shuffle_allframes/pep_free/pep_free_rep_0/fraction_60/training_pep_free_rep_0_frac_60.xtc
# [Fraction 70] Seed: 112 | Train frames: 3500 | Saved: Training_XTCs/not_shuffle_allframes/pep_free/pep_free_rep_0/fraction_70/training_pep_free_rep_0_frac_70.xtc
#
# === pep_free | rep 1 | not_shuffle_allframes ===
# Original frames: 5001
# [Fraction 10] Seed: 52 | Train frames: 500 | Saved: Training_XTCs/not_shuffle_allframes/pep_free/pep_free_rep_1/fraction_10/training_pep_free_rep_1_frac_10.xtc
# [Fraction 20] Seed: 62 | Train frames: 1000 | Saved: Training_XTCs/not_shuffle_allframes/pep_free/pep_free_rep_1/fraction_20/training_pep_free_rep_1_frac_20.xtc
# [Fraction 30] Seed: 72 | Train frames: 1500 | Saved: Training_XTCs/not_shuffle_allframes/pep_free/pep_free_rep_1/fraction_30/training_pep_free_rep_1_frac_30.xtc
# [Fraction 40] Seed: 82 | Train frames: 2000 | Saved: Training_XTCs/not_shuffle_allframes/pep_free/pep_free_rep_1/fraction_40/training_pep_free_rep_1_frac_40.xtc
# [Fraction 50] Seed: 92 | Train frames: 2500 | Saved: Training_XTCs/not_shuffle_allframes/pep_free/pep_free_rep_1/fraction_50/training_pep_free_rep_1_frac_50.xtc
# [Fraction 60] Seed: 102 | Train frames: 3000 | Saved: Training_XTCs/not_shuffle_allframes/pep_free/pep_free_rep_1/fraction_60/training_pep_free_rep_1_frac_60.xtc
# [Fraction 70] Seed: 112 | Train frames: 3500 | Saved: Training_XTCs/not_shuffle_allframes/pep_free/pep_free_rep_1/fraction_70/training_pep_free_rep_1_frac_70.xtc
#
# === pep_free | rep 2 | not_shuffle_allframes ===
# Original frames: 5001
# [Fraction 10] Seed: 52 | Train frames: 500 | Saved: Training_XTCs/not_shuffle_allframes/pep_free/pep_free_rep_2/fraction_10/training_pep_free_rep_2_frac_10.xtc
# [Fraction 20] Seed: 62 | Train frames: 1000 | Saved: Training_XTCs/not_shuffle_allframes/pep_free/pep_free_rep_2/fraction_20/training_pep_free_rep_2_frac_20.xtc
# [Fraction 30] Seed: 72 | Train frames: 1500 | Saved: Training_XTCs/not_shuffle_allframes/pep_free/pep_free_rep_2/fraction_30/training_pep_free_rep_2_frac_30.xtc
# [Fraction 40] Seed: 82 | Train frames: 2000 | Saved: Training_XTCs/not_shuffle_allframes/pep_free/pep_free_rep_2/fraction_40/training_pep_free_rep_2_frac_40.xtc
# [Fraction 50] Seed: 92 | Train frames: 2500 | Saved: Training_XTCs/not_shuffle_allframes/pep_free/pep_free_rep_2/fraction_50/training_pep_free_rep_2_frac_50.xtc
# [Fraction 60] Seed: 102 | Train frames: 3000 | Saved: Training_XTCs/not_shuffle_allframes/pep_free/pep_free_rep_2/fraction_60/training_pep_free_rep_2_frac_60.xtc
# [Fraction 70] Seed: 112 | Train frames: 3500 | Saved: Training_XTCs/not_shuffle_allframes/pep_free/pep_free_rep_2/fraction_70/training_pep_free_rep_2_frac_70.xtc
#
# === pep_free | rep 0 | not_shuffle_not_allframes ===
# Original frames: 5001
# [Fraction 10] Seed: 52 | Train frames: 485 | Saved: Training_XTCs/not_shuffle_not_allframes/pep_free/pep_free_rep_0/fraction_10/training_pep_free_rep_0_frac_10.xtc
# [Fraction 20] Seed: 62 | Train frames: 970 | Saved: Training_XTCs/not_shuffle_not_allframes/pep_free/pep_free_rep_0/fraction_20/training_pep_free_rep_0_frac_20.xtc
# [Fraction 30] Seed: 72 | Train frames: 1455 | Saved: Training_XTCs/not_shuffle_not_allframes/pep_free/pep_free_rep_0/fraction_30/training_pep_free_rep_0_frac_30.xtc
# [Fraction 40] Seed: 82 | Train frames: 1940 | Saved: Training_XTCs/not_shuffle_not_allframes/pep_free/pep_free_rep_0/fraction_40/training_pep_free_rep_0_frac_40.xtc
# [Fraction 50] Seed: 92 | Train frames: 2425 | Saved: Training_XTCs/not_shuffle_not_allframes/pep_free/pep_free_rep_0/fraction_50/training_pep_free_rep_0_frac_50.xtc
# [Fraction 60] Seed: 102 | Train frames: 2910 | Saved: Training_XTCs/not_shuffle_not_allframes/pep_free/pep_free_rep_0/fraction_60/training_pep_free_rep_0_frac_60.xtc
# [Fraction 70] Seed: 112 | Train frames: 3395 | Saved: Training_XTCs/not_shuffle_not_allframes/pep_free/pep_free_rep_0/fraction_70/training_pep_free_rep_0_frac_70.xtc
#
# === pep_free | rep 1 | not_shuffle_not_allframes ===
# Original frames: 5001
# [Fraction 10] Seed: 52 | Train frames: 485 | Saved: Training_XTCs/not_shuffle_not_allframes/pep_free/pep_free_rep_1/fraction_10/training_pep_free_rep_1_frac_10.xtc
# [Fraction 20] Seed: 62 | Train frames: 970 | Saved: Training_XTCs/not_shuffle_not_allframes/pep_free/pep_free_rep_1/fraction_20/training_pep_free_rep_1_frac_20.xtc
# [Fraction 30] Seed: 72 | Train frames: 1455 | Saved: Training_XTCs/not_shuffle_not_allframes/pep_free/pep_free_rep_1/fraction_30/training_pep_free_rep_1_frac_30.xtc
# [Fraction 40] Seed: 82 | Train frames: 1940 | Saved: Training_XTCs/not_shuffle_not_allframes/pep_free/pep_free_rep_1/fraction_40/training_pep_free_rep_1_frac_40.xtc
# [Fraction 50] Seed: 92 | Train frames: 2425 | Saved: Training_XTCs/not_shuffle_not_allframes/pep_free/pep_free_rep_1/fraction_50/training_pep_free_rep_1_frac_50.xtc
# [Fraction 60] Seed: 102 | Train frames: 2910 | Saved: Training_XTCs/not_shuffle_not_allframes/pep_free/pep_free_rep_1/fraction_60/training_pep_free_rep_1_frac_60.xtc
# [Fraction 70] Seed: 112 | Train frames: 3395 | Saved: Training_XTCs/not_shuffle_not_allframes/pep_free/pep_free_rep_1/fraction_70/training_pep_free_rep_1_frac_70.xtc
#
# === pep_free | rep 2 | not_shuffle_not_allframes ===
# Original frames: 5001
# [Fraction 10] Seed: 52 | Train frames: 485 | Saved: Training_XTCs/not_shuffle_not_allframes/pep_free/pep_free_rep_2/fraction_10/training_pep_free_rep_2_frac_10.xtc
# [Fraction 20] Seed: 62 | Train frames: 970 | Saved: Training_XTCs/not_shuffle_not_allframes/pep_free/pep_free_rep_2/fraction_20/training_pep_free_rep_2_frac_20.xtc
# [Fraction 30] Seed: 72 | Train frames: 1455 | Saved: Training_XTCs/not_shuffle_not_allframes/pep_free/pep_free_rep_2/fraction_30/training_pep_free_rep_2_frac_30.xtc
# [Fraction 40] Seed: 82 | Train frames: 1940 | Saved: Training_XTCs/not_shuffle_not_allframes/pep_free/pep_free_rep_2/fraction_40/training_pep_free_rep_2_frac_40.xtc
# [Fraction 50] Seed: 92 | Train frames: 2425 | Saved: Training_XTCs/not_shuffle_not_allframes/pep_free/pep_free_rep_2/fraction_50/training_pep_free_rep_2_frac_50.xtc
# [Fraction 60] Seed: 102 | Train frames: 2910 | Saved: Training_XTCs/not_shuffle_not_allframes/pep_free/pep_free_rep_2/fraction_60/training_pep_free_rep_2_frac_60.xtc
# [Fraction 70] Seed: 112 | Train frames: 3395 | Saved: Training_XTCs/not_shuffle_not_allframes/pep_free/pep_free_rep_2/fraction_70/training_pep_free_rep_2_frac_70.xtc

# %%
import sys
sys.path.append("../..")

from run_pipeline import run_pipeline

protein_id = "pep_free"
base_data_dir = "../../data/palantir_data/pep_free"

pdb_file = f"{base_data_dir}/{protein_id}.pdb"
atom_selection = "backbone"

latent_dim = 8
epochs = 300
batch_size = 64
kl_beta = 5e-5
base_seed = 42
device = "cuda"

replicas = [0, 1, 2]

experiments = [
    {
        "name": "shuffle_allframes",
        "use_all_frames": True,
        "shuffle_train": True,
        "base_out_dir": "../../Model_results/shuffle_allframes/pep_free"
    },
    {
        "name": "shuffle_not_allframes",
        "use_all_frames": False,
        "shuffle_train": True,
        "base_out_dir": "../../Model_results/shuffle_not_allframes/pep_free"
    },
    {
        "name": "not_shuffle_allframes",
        "use_all_frames": True,
        "shuffle_train": False,
        "base_out_dir": "../../Model_results/not_shuffle_allframes/pep_free"
    },
    {
        "name": "not_shuffle_not_allframes",
        "use_all_frames": False,
        "shuffle_train": False,
        "base_out_dir": "../../Model_results/not_shuffle_not_allframes/pep_free"
    }
]


condition_offsets = {
    "shuffle_allframes": 0,
    "shuffle_not_allframes": 1000,
    "not_shuffle_allframes": 2000,
    "not_shuffle_not_allframes": 3000,
}

for exp in experiments:

    print(f"\n**************************************")
    print(f"File Name: {exp['name']}")
    print(f"Parameters:\n use_all_frames={exp['use_all_frames']} | shuffle={exp['shuffle_train']}")
    print(f"**************************************")

    for rep in replicas:
        xtc_file = f"{base_data_dir}/{protein_id}_rep_{rep}.xtc"
        out_dir = f"{exp['base_out_dir']}/{protein_id}_rep_{rep}"

        run_seed = base_seed + condition_offsets[exp["name"]] + rep * 100

        print(f"\n--- RUNNING replica {rep} ---")
        print(f"Seed for this run: {run_seed}")
        
        run_pipeline(
            xtc_file=xtc_file,
            pdb_file=pdb_file,
            protein_id=protein_id,
            rep_num=str(rep),
            output_root=base_data_dir,
            atom_selection=atom_selection,
            out_dir=out_dir,
            already_preprocessed=False,
            latent_dim=latent_dim,
            epochs=epochs,
            batch_size=batch_size,
            kl_beta=kl_beta,
            use_all_frames=exp["use_all_frames"],
            shuffle_train=exp["shuffle_train"],
            seed=run_seed,
            device=device,
            fractions=(10, 20, 30, 40, 50, 60, 70),
            temperature=1.5,
            target_n_frames=1000,
            generation_batch_size=64,
            max_generation_attempts=50000,
            rama_outlier_threshold=0.10,
            bond_bad_threshold=0.15,
        )
# Out:
# **************************************
# File Name: shuffle_allframes
# Parameters:
#  use_all_frames=True | shuffle=True
# **************************************
#
# --- RUNNING replica 0 ---
# Seed for this run: 42
# [INFO] Frames: 5001, Atoms: 1504
# [Fraction 10] Seed: 52 | Train: 500 | Val: 500 | Test: 1000
# [Fraction 20] Seed: 62 | Train: 1000 | Val: 500 | Test: 1000
# [Fraction 30] Seed: 72 | Train: 1500 | Val: 500 | Test: 1000
# [Fraction 40] Seed: 82 | Train: 2000 | Val: 500 | Test: 1000
# [Fraction 50] Seed: 92 | Train: 2500 | Val: 500 | Test: 1000
# [Fraction 60] Seed: 102 | Train: 3000 | Val: 500 | Test: 1000
# [Fraction 70] Seed: 112 | Train: 3500 | Val: 500 | Test: 1000
#
# --- RUNNING replica 1 ---
# Seed for this run: 142
# [INFO] Frames: 5001, Atoms: 1504
# [Fraction 10] Seed: 152 | Train: 500 | Val: 500 | Test: 1000
# [Fraction 20] Seed: 162 | Train: 1000 | Val: 500 | Test: 1000
# [Fraction 30] Seed: 172 | Train: 1500 | Val: 500 | Test: 1000
# [Fraction 40] Seed: 182 | Train: 2000 | Val: 500 | Test: 1000
# [Fraction 50] Seed: 192 | Train: 2500 | Val: 500 | Test: 1000
# [Fraction 60] Seed: 202 | Train: 3000 | Val: 500 | Test: 1000
# [Fraction 70] Seed: 212 | Train: 3500 | Val: 500 | Test: 1000
#
# --- RUNNING replica 2 ---
# Seed for this run: 242
# [INFO] Frames: 5001, Atoms: 1504
# [Fraction 10] Seed: 252 | Train: 500 | Val: 500 | Test: 1000
# [Fraction 20] Seed: 262 | Train: 1000 | Val: 500 | Test: 1000
# [Fraction 30] Seed: 272 | Train: 1500 | Val: 500 | Test: 1000
# [Fraction 40] Seed: 282 | Train: 2000 | Val: 500 | Test: 1000
# [Fraction 50] Seed: 292 | Train: 2500 | Val: 500 | Test: 1000
# [Fraction 60] Seed: 302 | Train: 3000 | Val: 500 | Test: 1000
# [Fraction 70] Seed: 312 | Train: 3500 | Val: 500 | Test: 1000
#
# **************************************
# File Name: shuffle_not_allframes
# Parameters:
#  use_all_frames=False | shuffle=True
# **************************************
#
# --- RUNNING replica 0 ---
# Seed for this run: 1042
# [INFO] Frames: 5001, Atoms: 1504
# [Fraction 10] Seed: 1052 | Train: 485 | Val: 485 | Test: 970
# [Fraction 20] Seed: 1062 | Train: 970 | Val: 485 | Test: 970
# [Fraction 30] Seed: 1072 | Train: 1455 | Val: 485 | Test: 970
# [Fraction 40] Seed: 1082 | Train: 1940 | Val: 485 | Test: 970
# [Fraction 50] Seed: 1092 | Train: 2425 | Val: 485 | Test: 970
# [Fraction 60] Seed: 1102 | Train: 2910 | Val: 485 | Test: 970
# [Fraction 70] Seed: 1112 | Train: 3395 | Val: 485 | Test: 970
#
# --- RUNNING replica 1 ---
# Seed for this run: 1142
# [INFO] Frames: 5001, Atoms: 1504
# [Fraction 10] Seed: 1152 | Train: 485 | Val: 485 | Test: 970
# [Fraction 20] Seed: 1162 | Train: 970 | Val: 485 | Test: 970
# [Fraction 30] Seed: 1172 | Train: 1455 | Val: 485 | Test: 970
# [Fraction 40] Seed: 1182 | Train: 1940 | Val: 485 | Test: 970
# [Fraction 50] Seed: 1192 | Train: 2425 | Val: 485 | Test: 970
# [Fraction 60] Seed: 1202 | Train: 2910 | Val: 485 | Test: 970
# [Fraction 70] Seed: 1212 | Train: 3395 | Val: 485 | Test: 970
#
# --- RUNNING replica 2 ---
# Seed for this run: 1242
# [INFO] Frames: 5001, Atoms: 1504
# [Fraction 10] Seed: 1252 | Train: 485 | Val: 485 | Test: 970
# [Fraction 20] Seed: 1262 | Train: 970 | Val: 485 | Test: 970
# [Fraction 30] Seed: 1272 | Train: 1455 | Val: 485 | Test: 970
# [Fraction 40] Seed: 1282 | Train: 1940 | Val: 485 | Test: 970
# [Fraction 50] Seed: 1292 | Train: 2425 | Val: 485 | Test: 970
# [Fraction 60] Seed: 1302 | Train: 2910 | Val: 485 | Test: 970
# [Fraction 70] Seed: 1312 | Train: 3395 | Val: 485 | Test: 970
#
# **************************************
# File Name: not_shuffle_allframes
# Parameters:
#  use_all_frames=True | shuffle=False
# **************************************
#
# --- RUNNING replica 0 ---
# Seed for this run: 2042
# [INFO] Frames: 5001, Atoms: 1504
# [Fraction 10] Seed: 2052 | Train: 500 | Val: 500 | Test: 1000
# [Fraction 20] Seed: 2062 | Train: 1000 | Val: 500 | Test: 1000
# [Fraction 30] Seed: 2072 | Train: 1500 | Val: 500 | Test: 1000
# [Fraction 40] Seed: 2082 | Train: 2000 | Val: 500 | Test: 1000
# [Fraction 50] Seed: 2092 | Train: 2500 | Val: 500 | Test: 1000
# [Fraction 60] Seed: 2102 | Train: 3000 | Val: 500 | Test: 1000
# [Fraction 70] Seed: 2112 | Train: 3500 | Val: 500 | Test: 1000
#
# --- RUNNING replica 1 ---
# Seed for this run: 2142
# [INFO] Frames: 5001, Atoms: 1504
# [Fraction 10] Seed: 2152 | Train: 500 | Val: 500 | Test: 1000
# [Fraction 20] Seed: 2162 | Train: 1000 | Val: 500 | Test: 1000
# [Fraction 30] Seed: 2172 | Train: 1500 | Val: 500 | Test: 1000
# [Fraction 40] Seed: 2182 | Train: 2000 | Val: 500 | Test: 1000
# [Fraction 50] Seed: 2192 | Train: 2500 | Val: 500 | Test: 1000
# [Fraction 60] Seed: 2202 | Train: 3000 | Val: 500 | Test: 1000
# [Fraction 70] Seed: 2212 | Train: 3500 | Val: 500 | Test: 1000
#
# --- RUNNING replica 2 ---
# Seed for this run: 2242
# [INFO] Frames: 5001, Atoms: 1504
# [Fraction 10] Seed: 2252 | Train: 500 | Val: 500 | Test: 1000
# [Fraction 20] Seed: 2262 | Train: 1000 | Val: 500 | Test: 1000
# [Fraction 30] Seed: 2272 | Train: 1500 | Val: 500 | Test: 1000
# [Fraction 40] Seed: 2282 | Train: 2000 | Val: 500 | Test: 1000
# [Fraction 50] Seed: 2292 | Train: 2500 | Val: 500 | Test: 1000
# [Fraction 60] Seed: 2302 | Train: 3000 | Val: 500 | Test: 1000
# [Fraction 70] Seed: 2312 | Train: 3500 | Val: 500 | Test: 1000
#
# **************************************
# File Name: not_shuffle_not_allframes
# Parameters:
#  use_all_frames=False | shuffle=False
# **************************************
#
# --- RUNNING replica 0 ---
# Seed for this run: 3042
# [INFO] Frames: 5001, Atoms: 1504
# [Fraction 10] Seed: 3052 | Train: 485 | Val: 485 | Test: 970
# [Fraction 20] Seed: 3062 | Train: 970 | Val: 485 | Test: 970
# [Fraction 30] Seed: 3072 | Train: 1455 | Val: 485 | Test: 970
# [Fraction 40] Seed: 3082 | Train: 1940 | Val: 485 | Test: 970
# [Fraction 50] Seed: 3092 | Train: 2425 | Val: 485 | Test: 970
# [Fraction 60] Seed: 3102 | Train: 2910 | Val: 485 | Test: 970
# [Fraction 70] Seed: 3112 | Train: 3395 | Val: 485 | Test: 970
#
# --- RUNNING replica 1 ---
# Seed for this run: 3142
# [INFO] Frames: 5001, Atoms: 1504
# [Fraction 10] Seed: 3152 | Train: 485 | Val: 485 | Test: 970
# [Fraction 20] Seed: 3162 | Train: 970 | Val: 485 | Test: 970
# [Fraction 30] Seed: 3172 | Train: 1455 | Val: 485 | Test: 970
# [Fraction 40] Seed: 3182 | Train: 1940 | Val: 485 | Test: 970
# [Fraction 50] Seed: 3192 | Train: 2425 | Val: 485 | Test: 970
# [Fraction 60] Seed: 3202 | Train: 2910 | Val: 485 | Test: 970
# [Fraction 70] Seed: 3212 | Train: 3395 | Val: 485 | Test: 970
#
# --- RUNNING replica 2 ---
# Seed for this run: 3242
# [INFO] Frames: 5001, Atoms: 1504
# [Fraction 10] Seed: 3252 | Train: 485 | Val: 485 | Test: 970
# [Fraction 20] Seed: 3262 | Train: 970 | Val: 485 | Test: 970
# [Fraction 30] Seed: 3272 | Train: 1455 | Val: 485 | Test: 970
# [Fraction 40] Seed: 3282 | Train: 1940 | Val: 485 | Test: 970
# [Fraction 50] Seed: 3292 | Train: 2425 | Val: 485 | Test: 970
# [Fraction 60] Seed: 3302 | Train: 2910 | Val: 485 | Test: 970
# [Fraction 70] Seed: 3312 | Train: 3395 | Val: 485 | Test: 970

# %%
from model_analysis.outputs import *

base_dir = "../../Model_results"

conditions = [
    "shuffle_allframes",
    "shuffle_not_allframes",
    "not_shuffle_allframes",
    "not_shuffle_not_allframes"
]

protein_id = "pep_free"

for condition in conditions:

    experiment_dirs = {
        "rep_0": f"{base_dir}/{condition}/{protein_id}/{protein_id}_rep_0",
        "rep_1": f"{base_dir}/{condition}/{protein_id}/{protein_id}_rep_1",
        "rep_2": f"{base_dir}/{condition}/{protein_id}/{protein_id}_rep_2",
    }

    # 1) Training dynamics (replica-wise)
    model_accuracy_results_replica_wise(experiment_dirs)

    # 2) Summary performance (mean ± std)
    model_performance_results_combined(experiment_dirs)

# %% [markdown]
# # Equal frame number

# %%
import sys
sys.path.append("../..")

from run_pipeline import run_pipeline

protein_id = "pep_free"
base_data_dir = "../../data/palantir_data_equal_frames/pep_free"


pdb_file = f"{base_data_dir}/backbone.pdb"
atom_selection = "backbone"

latent_dim = 8
epochs = 300
batch_size = 64
kl_beta = 5e-5
base_seed = 42
device = "cuda"

replicas = [0, 1, 2]

experiments = [
    {
        "name": "shuffle_allframes",
        "use_all_frames": True,
        "shuffle_train": True,
        "base_out_dir": "../../Model_results/Equal_frames/shuffle_allframes/pep_free"
    },
    {
        "name": "shuffle_not_allframes",
        "use_all_frames": False,
        "shuffle_train": True,
        "base_out_dir": "../../Model_results/Equal_frames/shuffle_not_allframes/pep_free"
    },
    {
        "name": "not_shuffle_allframes",
        "use_all_frames": True,
        "shuffle_train": False,
        "base_out_dir": "../../Model_results/Equal_frames/not_shuffle_allframes/pep_free"
    },
    {
        "name": "not_shuffle_not_allframes",
        "use_all_frames": False,
        "shuffle_train": False,
        "base_out_dir": "../../Model_results/Equal_frames/not_shuffle_not_allframes/pep_free"
    }
]

condition_offsets = {
    "shuffle_allframes": 0,
    "shuffle_not_allframes": 1000,
    "not_shuffle_allframes": 2000,
    "not_shuffle_not_allframes": 3000,
}

for exp in experiments:

    print(f"\n**************************************")
    print(f"File Name: {exp['name']}")
    print(f"Parameters:\n use_all_frames={exp['use_all_frames']} | shuffle={exp['shuffle_train']}")
    print(f"**************************************")

    for rep in replicas:
        xtc_file = f"{base_data_dir}/{protein_id}_rep_{rep}_backbone.xtc"
        out_dir = f"{exp['base_out_dir']}/{protein_id}_rep_{rep}"

    
        run_seed = base_seed + condition_offsets[exp["name"]] + rep * 100

        print(f"\n--- RUNNING replica {rep} ---")
        print(f"Seed for this run: {run_seed}")

        run_pipeline(
            xtc_file=xtc_file,
            pdb_file=pdb_file,
            protein_id=protein_id,
            rep_num=str(rep),
            output_root=base_data_dir,
            atom_selection=atom_selection,
            out_dir=out_dir,
            already_preprocessed=True,
            latent_dim=latent_dim,
            epochs=epochs,
            batch_size=batch_size,
            kl_beta=kl_beta,
            use_all_frames=exp["use_all_frames"],
            shuffle_train=exp["shuffle_train"],
            seed=run_seed,
            device=device,
            fractions=(10, 20, 30, 40, 50, 60, 70),
            temperature=1.5,
            target_n_frames=1000,
            generation_batch_size=64,
            max_generation_attempts=50000,
            rama_outlier_threshold=0.10,
            bond_bad_threshold=0.15,
        )
# Out:
# **************************************
# File Name: shuffle_allframes
# Parameters:
#  use_all_frames=True | shuffle=True
# **************************************
#
# --- RUNNING replica 0 ---
# Seed for this run: 42
# [INFO] Frames: 875, Atoms: 1504
# [Fraction 10] Seed: 52 | Train: 87 | Val: 87 | Test: 175
# [Fraction 20] Seed: 62 | Train: 175 | Val: 87 | Test: 175
# [Fraction 30] Seed: 72 | Train: 262 | Val: 87 | Test: 175
# [Fraction 40] Seed: 82 | Train: 350 | Val: 87 | Test: 175
# [Fraction 50] Seed: 92 | Train: 437 | Val: 87 | Test: 175
# [Fraction 60] Seed: 102 | Train: 525 | Val: 87 | Test: 175
# [Fraction 70] Seed: 112 | Train: 612 | Val: 87 | Test: 175
#
# --- RUNNING replica 1 ---
# Seed for this run: 142
# [INFO] Frames: 875, Atoms: 1504
# [Fraction 10] Seed: 152 | Train: 87 | Val: 87 | Test: 175
# [Fraction 20] Seed: 162 | Train: 175 | Val: 87 | Test: 175
# [Fraction 30] Seed: 172 | Train: 262 | Val: 87 | Test: 175
# [Fraction 40] Seed: 182 | Train: 350 | Val: 87 | Test: 175
# [Fraction 50] Seed: 192 | Train: 437 | Val: 87 | Test: 175
# [Fraction 60] Seed: 202 | Train: 525 | Val: 87 | Test: 175
# [Fraction 70] Seed: 212 | Train: 612 | Val: 87 | Test: 175
#
# --- RUNNING replica 2 ---
# Seed for this run: 242
# [INFO] Frames: 875, Atoms: 1504
# [Fraction 10] Seed: 252 | Train: 87 | Val: 87 | Test: 175
# [Fraction 20] Seed: 262 | Train: 175 | Val: 87 | Test: 175
# [Fraction 30] Seed: 272 | Train: 262 | Val: 87 | Test: 175
# [Fraction 40] Seed: 282 | Train: 350 | Val: 87 | Test: 175
# [Fraction 50] Seed: 292 | Train: 437 | Val: 87 | Test: 175
# [Fraction 60] Seed: 302 | Train: 525 | Val: 87 | Test: 175
# [Fraction 70] Seed: 312 | Train: 612 | Val: 87 | Test: 175
#
# **************************************
# File Name: shuffle_not_allframes
# Parameters:
#  use_all_frames=False | shuffle=True
# **************************************
#
# --- RUNNING replica 0 ---
# Seed for this run: 1042
# [INFO] Frames: 875, Atoms: 1504
# [Fraction 10] Seed: 1052 | Train: 72 | Val: 72 | Test: 145
# [Fraction 20] Seed: 1062 | Train: 145 | Val: 72 | Test: 145
# [Fraction 30] Seed: 1072 | Train: 217 | Val: 72 | Test: 145
# [Fraction 40] Seed: 1082 | Train: 290 | Val: 72 | Test: 145
# [Fraction 50] Seed: 1092 | Train: 362 | Val: 72 | Test: 145
# [Fraction 60] Seed: 1102 | Train: 435 | Val: 72 | Test: 145
# [Fraction 70] Seed: 1112 | Train: 507 | Val: 72 | Test: 145
#
# --- RUNNING replica 1 ---
# Seed for this run: 1142
# [INFO] Frames: 875, Atoms: 1504
# [Fraction 10] Seed: 1152 | Train: 72 | Val: 72 | Test: 145
# [Fraction 20] Seed: 1162 | Train: 145 | Val: 72 | Test: 145
# [Fraction 30] Seed: 1172 | Train: 217 | Val: 72 | Test: 145
# [Fraction 40] Seed: 1182 | Train: 290 | Val: 72 | Test: 145
# [Fraction 50] Seed: 1192 | Train: 362 | Val: 72 | Test: 145
# [Fraction 60] Seed: 1202 | Train: 435 | Val: 72 | Test: 145
# [Fraction 70] Seed: 1212 | Train: 507 | Val: 72 | Test: 145
#
# --- RUNNING replica 2 ---
# Seed for this run: 1242
# [INFO] Frames: 875, Atoms: 1504
# [Fraction 10] Seed: 1252 | Train: 72 | Val: 72 | Test: 145
# [Fraction 20] Seed: 1262 | Train: 145 | Val: 72 | Test: 145
# [Fraction 30] Seed: 1272 | Train: 217 | Val: 72 | Test: 145
# [Fraction 40] Seed: 1282 | Train: 290 | Val: 72 | Test: 145
# [Fraction 50] Seed: 1292 | Train: 362 | Val: 72 | Test: 145
# [Fraction 60] Seed: 1302 | Train: 435 | Val: 72 | Test: 145
# [Fraction 70] Seed: 1312 | Train: 507 | Val: 72 | Test: 145
#
# **************************************
# File Name: not_shuffle_allframes
# Parameters:
#  use_all_frames=True | shuffle=False
# **************************************
#
# --- RUNNING replica 0 ---
# Seed for this run: 2042
# [INFO] Frames: 875, Atoms: 1504
# [Fraction 10] Seed: 2052 | Train: 87 | Val: 87 | Test: 175
# [Fraction 20] Seed: 2062 | Train: 175 | Val: 87 | Test: 175
# [Fraction 30] Seed: 2072 | Train: 262 | Val: 87 | Test: 175
# [Fraction 40] Seed: 2082 | Train: 350 | Val: 87 | Test: 175
# [Fraction 50] Seed: 2092 | Train: 437 | Val: 87 | Test: 175
# [Fraction 60] Seed: 2102 | Train: 525 | Val: 87 | Test: 175
# [Fraction 70] Seed: 2112 | Train: 612 | Val: 87 | Test: 175
#
# --- RUNNING replica 1 ---
# Seed for this run: 2142
# [INFO] Frames: 875, Atoms: 1504
# [Fraction 10] Seed: 2152 | Train: 87 | Val: 87 | Test: 175
# [Fraction 20] Seed: 2162 | Train: 175 | Val: 87 | Test: 175
# [Fraction 30] Seed: 2172 | Train: 262 | Val: 87 | Test: 175
# [Fraction 40] Seed: 2182 | Train: 350 | Val: 87 | Test: 175
# [Fraction 50] Seed: 2192 | Train: 437 | Val: 87 | Test: 175
# [Fraction 60] Seed: 2202 | Train: 525 | Val: 87 | Test: 175
# [Fraction 70] Seed: 2212 | Train: 612 | Val: 87 | Test: 175
#
# --- RUNNING replica 2 ---
# Seed for this run: 2242
# [INFO] Frames: 875, Atoms: 1504
# [Fraction 10] Seed: 2252 | Train: 87 | Val: 87 | Test: 175
# [Fraction 20] Seed: 2262 | Train: 175 | Val: 87 | Test: 175
# [Fraction 30] Seed: 2272 | Train: 262 | Val: 87 | Test: 175
# [Fraction 40] Seed: 2282 | Train: 350 | Val: 87 | Test: 175
# [Fraction 50] Seed: 2292 | Train: 437 | Val: 87 | Test: 175
# [Fraction 60] Seed: 2302 | Train: 525 | Val: 87 | Test: 175
# [Fraction 70] Seed: 2312 | Train: 612 | Val: 87 | Test: 175
#
# **************************************
# File Name: not_shuffle_not_allframes
# Parameters:
#  use_all_frames=False | shuffle=False
# **************************************
#
# --- RUNNING replica 0 ---
# Seed for this run: 3042
# [INFO] Frames: 875, Atoms: 1504
# [Fraction 10] Seed: 3052 | Train: 72 | Val: 72 | Test: 145
# [Fraction 20] Seed: 3062 | Train: 145 | Val: 72 | Test: 145
# [Fraction 30] Seed: 3072 | Train: 217 | Val: 72 | Test: 145
# [Fraction 40] Seed: 3082 | Train: 290 | Val: 72 | Test: 145
# [Fraction 50] Seed: 3092 | Train: 362 | Val: 72 | Test: 145
# [Fraction 60] Seed: 3102 | Train: 435 | Val: 72 | Test: 145
# [Fraction 70] Seed: 3112 | Train: 507 | Val: 72 | Test: 145
#
# --- RUNNING replica 1 ---
# Seed for this run: 3142
# [INFO] Frames: 875, Atoms: 1504
# [Fraction 10] Seed: 3152 | Train: 72 | Val: 72 | Test: 145
# [Fraction 20] Seed: 3162 | Train: 145 | Val: 72 | Test: 145
# [Fraction 30] Seed: 3172 | Train: 217 | Val: 72 | Test: 145
# [Fraction 40] Seed: 3182 | Train: 290 | Val: 72 | Test: 145
# [Fraction 50] Seed: 3192 | Train: 362 | Val: 72 | Test: 145
# [Fraction 60] Seed: 3202 | Train: 435 | Val: 72 | Test: 145
# [Fraction 70] Seed: 3212 | Train: 507 | Val: 72 | Test: 145
#
# --- RUNNING replica 2 ---
# Seed for this run: 3242
# [INFO] Frames: 875, Atoms: 1504
# [Fraction 10] Seed: 3252 | Train: 72 | Val: 72 | Test: 145
# [Fraction 20] Seed: 3262 | Train: 145 | Val: 72 | Test: 145
# [Fraction 30] Seed: 3272 | Train: 217 | Val: 72 | Test: 145
# [Fraction 40] Seed: 3282 | Train: 290 | Val: 72 | Test: 145
# [Fraction 50] Seed: 3292 | Train: 362 | Val: 72 | Test: 145
# [Fraction 60] Seed: 3302 | Train: 435 | Val: 72 | Test: 145
# [Fraction 70] Seed: 3312 | Train: 507 | Val: 72 | Test: 145

# %%
from model_analysis.outputs import *

base_dir = "../../Model_results/Equal_frames"

conditions = [
    "shuffle_allframes",
    "shuffle_not_allframes",
    "not_shuffle_allframes",
    "not_shuffle_not_allframes"
]

protein_id = "pep_free"

for condition in conditions:

    experiment_dirs = {
        "rep_0": f"{base_dir}/{condition}/{protein_id}/{protein_id}_rep_0",
        "rep_1": f"{base_dir}/{condition}/{protein_id}/{protein_id}_rep_1",
        "rep_2": f"{base_dir}/{condition}/{protein_id}/{protein_id}_rep_2",
    }

    # 1) Training dynamics (replica-wise)
    model_accuracy_results_replica_wise(experiment_dirs)

    # 2) Summary performance (mean ± std)
    model_performance_results_combined(experiment_dirs)
