# %%
import sys
sys.path.append("..")
import mdtraj as md
import os
import numpy as np
from Accuracy_metrics_pipeline import *
from analysis_plots import *
from analysis_io import save_figure, save_array_txt

# %% [markdown]
# # Pep Free Replica 0

# %% [markdown]
# #### Fraction 20 (Train %20 Test %80)

# %%
gen_traj_20_0 = "../pep_free/pep_free_rep_0/fraction_20/generated_frac_20.xtc"
ref_traj_20_0 = "../../data/palantir_data/pep_free/pep_free_rep_0_backbone.xtc"
pdb = "../../data/palantir_data/pep_free/backbone.pdb"


gen_traj_20_0, ref_traj_20_0 = data_preprocessing(
    gen_traj = gen_traj_20_0,
    ref_traj = ref_traj_20_0,
    backbone_pdb = pdb
)

# RMSD
rmsd_gen_20_0, rmsd_ref_20_0 = rmsd_internal(gen_traj_20_0, ref_traj_20_0)

# RMSF
res_ids_20_0, rmsf_ref_20_0, rmsf_gen_20_0 = rmsf_md_vs_gen(gen_traj_20_0, ref_traj_20_0)

# Rg
rg_gen_20_0, rg_ref_20_0 = radius_of_gyration(gen_traj_20_0, ref_traj_20_0)

# Ramachandran
phi_r_20_0, psi_r_20_0, phi_g_20_0, psi_g_20_0 = compute_phi_psi(gen_traj_20_0, ref_traj_20_0)

# DSSP
dssp_ref_20_0, dssp_gen_20_0, frac_md_20_0, frac_gen_20_0, delta_h_20_0 = dssp_analysis(ref_traj_20_0, gen_traj_20_0)

# Contact map
cm_ref_20_0 = compute_contact_map(ref_traj_20_0)
cm_gen_20_0 = compute_contact_map(gen_traj_20_0)

# PCA
X_ref_pca_20_0, X_gen_pca_20_0 = pca(gen_traj_20_0, ref_traj_20_0)

# %%
out_dir_20_0 = '../results/pep_free_0/fraction_20'

fig_rmsd_20_0 = plot_rmsd(rmsd_ref_20_0, rmsd_gen_20_0)
save_figure(fig_rmsd_20_0, f"{out_dir_20_0}/rmsd.png")

save_array_txt(rmsd_ref_20_0, f"{out_dir_20_0}/rmsd_ref.txt")
save_array_txt(rmsd_gen_20_0, f"{out_dir_20_0}/rmsd_gen.txt")


fig_rmsf_20_0 = plot_rmsf(res_ids_20_0, rmsf_ref_20_0, rmsf_gen_20_0)
save_figure(fig_rmsf_20_0, f"{out_dir_20_0}/rmsf.png")

save_array_txt(rmsf_ref_20_0, f"{out_dir_20_0}/rmsf_ref.txt")
save_array_txt(rmsf_gen_20_0, f"{out_dir_20_0}/rmsf_gen.txt")
save_array_txt(res_ids_20_0, f"{out_dir_20_0}/res__ids.txt")

fig_rg_20_0 = plot_rg(rg_ref_20_0, rg_gen_20_0)
save_figure(fig_rg_20_0 , f"{out_dir_20_0}/rg.png")

save_array_txt(rg_ref_20_0, f"{out_dir_20_0}/rg_ref.txt")
save_array_txt(rg_gen_20_0, f"{out_dir_20_0}/rg_gen.txt")

fig_ramachandran_20_0 = plot_ramachandran(phi_r_20_0, psi_r_20_0, phi_g_20_0, psi_g_20_0)
save_figure(fig_ramachandran_20_0, f"{out_dir_20_0}/ramachandran.png")

fig_dssp_20_0 = plot_dssp_fractions(frac_md_20_0, frac_gen_20_0)
save_figure(fig_dssp_20_0, f"{out_dir_20_0}/dssp_fractions.png")

fig_dssp_delta_20_0 =  plot_dssp_delta_helix(delta_h_20_0)
save_figure(fig_dssp_delta_20_0, f"{out_dir_20_0}/dssp_delta.png")

fig_contact_ref_20_0 = plot_contact_map(cm_ref_20_0, title="Contact Map REF")
fig_contact_gen_20_0 = plot_contact_map(cm_gen_20_0, title="Contact Map GEN")
save_figure(fig_contact_ref_20_0, f"{out_dir_20_0}/contact_map_ref.png")
save_figure(fig_contact_gen_20_0, f"{out_dir_20_0}/contact_map_gen.png")


fig_pca_20_0 = plot_pca(X_ref_pca_20_0, X_gen_pca_20_0)
save_figure(fig_pca_20_0, f"{out_dir_20_0}/pca.png")

# %% [markdown]
# #### Fraction 40 (Train %40 Test %60)

# %%
gen_traj_40_0 = "../pep_free/pep_free_rep_0/fraction_40/generated_frac_40.xtc"
ref_traj_40_0 = "../../data/palantir_data/pep_free/pep_free_rep_0_backbone.xtc"
pdb = "../../data/palantir_data/pep_free/backbone.pdb"


gen_traj_40_0, ref_traj_40_0 = data_preprocessing(
    gen_traj = gen_traj_40_0,
    ref_traj = ref_traj_40_0,
    backbone_pdb = pdb
)

# RMSD
rmsd_gen_40_0, rmsd_ref_40_0= rmsd_internal(gen_traj_40_0, ref_traj_40_0)

# RMSF
res_ids_40_0, rmsf_ref_40_0, rmsf_gen_40_0 = rmsf_md_vs_gen(gen_traj_40_0, ref_traj_40_0)

# Rg
rg_gen_40_0, rg_ref_40_0 = radius_of_gyration(gen_traj_40_0, ref_traj_40_0)

# Ramachandran
phi_r_40_0, psi_r_40_0, phi_g_40_0, psi_g_40_0 = compute_phi_psi(gen_traj_40_0, ref_traj_40_0)

# DSSP
dssp_ref_40_0, dssp_gen_40_0, frac_md_40_0, frac_gen_40_0, delta_h_40_0 = dssp_analysis(ref_traj_40_0, gen_traj_40_0)

# Contact map
cm_ref_40_0 = compute_contact_map(ref_traj_40_0)
cm_gen_40_0 = compute_contact_map(gen_traj_40_0)

# PCA
X_ref_pca_40_0, X_gen_pca_40_0 = pca(gen_traj_40_0, ref_traj_40_0)

# %%
out_dir_40_0 = '../results/pep_free_0/fraction_40'


fig_rmsd_40_0 = plot_rmsd(rmsd_ref_40_0 , rmsd_gen_40_0)
save_figure(fig_rmsd_40_0, f"{out_dir_40_0}/rmsd.png")

save_array_txt(rmsd_ref_40_0,f"{out_dir_40_0}/rmsd_ref.txt")
save_array_txt(rmsd_gen_40_0,f"{out_dir_40_0}/rmsd_gen.txt")


fig_rmsf_40_0 = plot_rmsf(res_ids_40_0, rmsf_ref_40_0, rmsf_gen_40_0)
save_figure(fig_rmsf_40_0,f"{out_dir_40_0}/rmsf.png")

save_array_txt(rmsf_ref_40_0,f"{out_dir_40_0}/rmsf_ref.txt")
save_array_txt(rmsf_gen_40_0,f"{out_dir_40_0}/rmsf_gen.txt")
save_array_txt(res_ids_40_0,f"{out_dir_40_0}/res__ids.txt")

fig_rg_40_0 = plot_rg(rg_ref_40_0, rg_gen_40_0)
save_figure(fig_rg_40_0 , f"{out_dir_40_0}/rg.png")

save_array_txt(rg_ref_40_0, f"{out_dir_40_0}/rg_ref.txt")
save_array_txt(rg_gen_40_0, f"{out_dir_40_0}/rg_gen.txt")

fig_ramachandran_40_0 = plot_ramachandran(phi_r_40_0, psi_r_40_0, phi_g_40_0, psi_g_40_0,)
save_figure(fig_ramachandran_40_0, f"{out_dir_40_0}/ramachandran.png")

fig_dssp_40_0 = plot_dssp_fractions(frac_md_40_0, frac_gen_40_0)
save_figure(fig_dssp_40_0, f"{out_dir_40_0}/dssp_fractions.png")

fig_dssp_delta_40_0 =  plot_dssp_delta_helix(delta_h_40_0)
save_figure(fig_dssp_delta_40_0,f"{out_dir_40_0}/dssp_delta.png")

fig_contact_ref_40_0 = plot_contact_map(cm_ref_40_0, title="Contact Map REF")
fig_contact_gen_40_0 = plot_contact_map(cm_gen_40_0, title="Contact Map GEN")
save_figure(fig_contact_ref_40_0,f"{out_dir_40_0}/contact_map_ref.png")
save_figure(fig_contact_gen_40_0,f"{out_dir_40_0}/contact_map_gen.png")



fig_pca_40_0 = plot_pca(X_ref_pca_40_0, X_gen_pca_40_0)
save_figure(fig_pca_40_0, f"{out_dir_40_0}/pca.png")

# %% [markdown]
# #### Fraction 60 (Train %60 Test %40)

# %%
gen_traj_60_0 = "../pep_free/pep_free_rep_0/fraction_60/generated_frac_60.xtc"
ref_traj_60_0 = "../../data/palantir_data/pep_free/pep_free_rep_0_backbone.xtc"
pdb = "../../data/palantir_data/pep_free/backbone.pdb"


gen_traj_60_0, ref_traj_60_0 = data_preprocessing(
    gen_traj = gen_traj_60_0,
    ref_traj = ref_traj_60_0,
    backbone_pdb = pdb
)

# RMSD
rmsd_gen_60_0, rmsd_ref_60_0 = rmsd_internal(gen_traj_60_0, ref_traj_60_0)

# RMSF
res_ids_60_0, rmsf_ref_60_0, rmsf_gen_60_0 = rmsf_md_vs_gen(gen_traj_60_0, ref_traj_60_0)

# Rg
rg_gen_60_0, rg_ref_60_0 = radius_of_gyration(gen_traj_60_0, ref_traj_60_0)

# Ramachandran
phi_r_60_0, psi_r_60_0, phi_g_60_0, psi_g_60_0 = compute_phi_psi(gen_traj_60_0, ref_traj_60_0)

# DSSP
dssp_ref_60_0, dssp_gen_60_0, frac_md_60_0, frac_gen_60_0, delta_h_60_0 = dssp_analysis(ref_traj_60_0, gen_traj_60_0)

# Contact map
cm_ref_60_0 = compute_contact_map(ref_traj_60_0)
cm_gen_60_0 = compute_contact_map(gen_traj_60_0)

# PCA
X_ref_pca_60_0, X_gen_pca_60_0 = pca(gen_traj_60_0, ref_traj_60_0)

# %%
out_dir_60_0 = '../results/pep_free_0/fraction_60'

fig_rmsd_60_0 = plot_rmsd(rmsd_ref_60_0, rmsd_gen_60_0)
save_figure(fig_rmsd_60_0, f'{out_dir_60_0}/rmsd.png')

save_array_txt(rmsd_ref_60_0,f'{out_dir_60_0}/rmsd_ref.txt')
save_array_txt(rmsd_gen_60_0, f'{out_dir_60_0}/rmsd_gen.txt')


fig_rmsf_60_0 = plot_rmsf(res_ids_60_0, rmsf_ref_60_0, rmsf_gen_60_0)
save_figure(fig_rmsf_60_0,f"{out_dir_60_0}/rmsf.png")

save_array_txt(rmsf_ref_60_0, f"{out_dir_60_0}/rmsf_ref.txt")
save_array_txt(rmsf_gen_60_0, f"{out_dir_60_0}/rmsf_gen.txt")
save_array_txt(res_ids_60_0, f"{out_dir_60_0}/res__ids.txt")

fig_rg_60_0 = plot_rg(rg_ref_60_0, rg_gen_60_0)
save_figure(fig_rg_60_0 , f"{out_dir_60_0}/rg.png")

save_array_txt(rg_ref_60_0, f"{out_dir_60_0}/rg_ref.txt")
save_array_txt(rg_gen_60_0, f"{out_dir_60_0}/rg_gen.txt")

fig_ramachandran_60_0 = plot_ramachandran(phi_r_60_0, psi_r_60_0, phi_g_60_0, psi_g_60_0)
save_figure(fig_ramachandran_60_0, f"{out_dir_60_0}/ramachandran.png")

fig_dssp_60_0 = plot_dssp_fractions(frac_md_60_0, frac_gen_60_0)
save_figure(fig_dssp_60_0, f"{out_dir_60_0}/dssp_fractions.png")

fig_dssp_delta_60_0 =  plot_dssp_delta_helix(delta_h_60_0)
save_figure(fig_dssp_delta_60_0, f"{out_dir_60_0}/dssp_delta.png")

fig_contact_ref_60_0 = plot_contact_map(cm_ref_60_0, title="Contact Map REF")
fig_contact_gen_60_0 = plot_contact_map(cm_gen_60_0, title="Contact Map GEN")
save_figure(fig_contact_ref_60_0, f"{out_dir_60_0}/contact_map_ref.png")
save_figure(fig_contact_gen_60_0, f"{out_dir_60_0}/contact_map_gen.png")



fig_pca_60_0 = plot_pca(X_ref_pca_60_0, X_gen_pca_60_0)
save_figure(fig_pca_60_0, f"{out_dir_60_0}/pca.png")

# %% [markdown]
# # Pep Free Replica 1

# %% [markdown]
# #### Fraction 20 (Train %20 Test %80)

# %%
gen_traj_20_1 = "../pep_free/pep_free_rep_1/fraction_20/generated_frac_20.xtc"
ref_traj_20_1 = "../../data/palantir_data/pep_free/pep_free_rep_1_backbone.xtc"
pdb = "../../data/palantir_data/pep_free/backbone.pdb"



gen_traj_20_1, ref_traj_20_1 = data_preprocessing(
    gen_traj = gen_traj_20_1,
    ref_traj = ref_traj_20_1,
    backbone_pdb = pdb
)

# RMSD
rmsd_gen_20_1, rmsd_ref_20_1 = rmsd_internal(gen_traj_20_1, ref_traj_20_1)

# RMSF
res_ids_20_1, rmsf_ref_20_1, rmsf_gen_20_1 = rmsf_md_vs_gen(gen_traj_20_1, ref_traj_20_1)

# Rg
rg_gen_20_1, rg_ref_20_1 = radius_of_gyration(gen_traj_20_1, ref_traj_20_1)

# Ramachandran
phi_r_20_1, psi_r_20_1, phi_g_20_1, psi_g_20_1 = compute_phi_psi(gen_traj_20_1, ref_traj_20_1)

# DSSP
dssp_ref_20_1, dssp_gen_20_1, frac_md_20_1, frac_gen_20_1, delta_h_20_1 = dssp_analysis(ref_traj_20_1, gen_traj_20_1)

# Contact map
cm_ref_20_1 = compute_contact_map(ref_traj_20_1)
cm_gen_20_1 = compute_contact_map(gen_traj_20_1)

# PCA
X_ref_pca_20_1, X_gen_pca_20_1 = pca(gen_traj_20_1, ref_traj_20_1)

# %%
out_dir_20_1 = '../results/pep_free_1/fraction_20'

fig_rmsd_20_1 = plot_rmsd(rmsd_ref_20_1, rmsd_gen_20_1)
save_figure(fig_rmsd_20_1, f"{out_dir_20_1}/rmsd.png")

save_array_txt(rmsd_ref_20_1, f"{out_dir_20_1}/rmsd_ref.txt")
save_array_txt(rmsd_gen_20_1, f"{out_dir_20_1}/rmsd_gen.txt")


fig_rmsf_20_1 = plot_rmsf(res_ids_20_1, rmsf_ref_20_1, rmsf_gen_20_1)
save_figure(fig_rmsf_20_1, f"{out_dir_20_1}/rmsf.png")

save_array_txt(rmsf_ref_20_1, f"{out_dir_20_1}/rmsf_ref.txt")
save_array_txt(rmsf_gen_20_1, f"{out_dir_20_1}/rmsf_gen.txt")
save_array_txt(res_ids_20_1, f"{out_dir_20_1}/res__ids.txt")

fig_rg_20_1 = plot_rg(rg_ref_20_1, rg_gen_20_1)
save_figure(fig_rg_20_1 , f"{out_dir_20_1}/rg.png")

save_array_txt(rg_ref_20_1, f"{out_dir_20_1}/rg_ref.txt")
save_array_txt(rg_gen_20_1, f"{out_dir_20_1}/rg_gen.txt")

fig_ramachandran_20_1 = plot_ramachandran(phi_r_20_1, psi_r_20_1, phi_g_20_1, psi_g_20_1)
save_figure(fig_ramachandran_20_1, f"{out_dir_20_1}/ramachandran.png")

fig_dssp_20_1 = plot_dssp_fractions(frac_md_20_1, frac_gen_20_1)
save_figure(fig_dssp_20_1, f"{out_dir_20_1}/dssp_fractions.png")

fig_dssp_delta_20_1 =  plot_dssp_delta_helix(delta_h_20_1)
save_figure(fig_dssp_delta_20_1, f"{out_dir_20_1}/dssp_delta.png")

fig_contact_ref_20_1 = plot_contact_map(cm_ref_20_1, title="Contact Map REF")
fig_contact_gen_20_1 = plot_contact_map(cm_gen_20_1, title="Contact Map GEN")
save_figure(fig_contact_ref_20_1, f"{out_dir_20_1}/contact_map_ref.png")
save_figure(fig_contact_gen_20_1, f"{out_dir_20_1}/contact_map_gen.png")


fig_pca_20_1 = plot_pca(X_ref_pca_20_1, X_gen_pca_20_1)
save_figure(fig_pca_20_1, f"{out_dir_20_1}/pca.png")

# %% [markdown]
# #### Fraction 40 (Train %40 Test %60)

# %%
gen_traj_40_1 = "../pep_free/pep_free_rep_1/fraction_40/generated_frac_40.xtc"
ref_traj_40_1 = "../../data/palantir_data/pep_free/pep_free_rep_1_backbone.xtc"
pdb = "../../data/palantir_data/pep_free/backbone.pdb"


gen_traj_40_1, ref_traj_40_1 = data_preprocessing(
    gen_traj = gen_traj_40_1,
    ref_traj = ref_traj_40_1,
    backbone_pdb = pdb
)

# RMSD
rmsd_gen_40_1, rmsd_ref_40_1= rmsd_internal(gen_traj_40_1, ref_traj_40_1)

# RMSF
res_ids_40_1, rmsf_ref_40_1, rmsf_gen_40_1 = rmsf_md_vs_gen(gen_traj_40_1, ref_traj_40_1)

# Rg
rg_gen_40_1, rg_ref_40_1 = radius_of_gyration(gen_traj_40_1, ref_traj_40_1)

# Ramachandran
phi_r_40_1, psi_r_40_1, phi_g_40_1, psi_g_40_1 = compute_phi_psi(gen_traj_40_1, ref_traj_40_1)

# DSSP
dssp_ref_40_1, dssp_gen_40_1, frac_md_40_1, frac_gen_40_1, delta_h_40_1 = dssp_analysis(ref_traj_40_1, gen_traj_40_1)

# Contact map
cm_ref_40_1 = compute_contact_map(ref_traj_40_1)
cm_gen_40_1 = compute_contact_map(gen_traj_40_1)

# PCA
X_ref_pca_40_1, X_gen_pca_40_1 = pca(gen_traj_40_1, ref_traj_40_1)
X_ref_pca_40_0, X_gen_pca_40_0 = pca(gen_traj_40_0, ref_traj_40_0)

# %%
out_dir_40_1 = '../results/pep_free_1/fraction_40'


fig_rmsd_40_1 = plot_rmsd(rmsd_ref_40_1 , rmsd_gen_40_1)
save_figure(fig_rmsd_40_1, f"{out_dir_40_1}/rmsd.png")

save_array_txt(rmsd_ref_40_1,f"{out_dir_40_1}/rmsd_ref.txt")
save_array_txt(rmsd_gen_40_1,f"{out_dir_40_1}/rmsd_gen.txt")


fig_rmsf_40_1 = plot_rmsf(res_ids_40_1, rmsf_ref_40_1, rmsf_gen_40_1)
save_figure(fig_rmsf_40_1,f"{out_dir_40_1}/rmsf.png")

save_array_txt(rmsf_ref_40_1,f"{out_dir_40_1}/rmsf_ref.txt")
save_array_txt(rmsf_gen_40_1,f"{out_dir_40_1}/rmsf_gen.txt")
save_array_txt(res_ids_40_1,f"{out_dir_40_1}/res__ids.txt")

fig_rg_40_1 = plot_rg(rg_ref_40_1, rg_gen_40_1)
save_figure(fig_rg_40_1 , f"{out_dir_40_1}/rg.png")

save_array_txt(rg_ref_40_1, f"{out_dir_40_1}/rg_ref.txt")
save_array_txt(rg_gen_40_1, f"{out_dir_40_1}/rg_gen.txt")

fig_ramachandran_40_1 = plot_ramachandran(phi_r_40_1, psi_r_40_1, phi_g_40_1, psi_g_40_1)
save_figure(fig_ramachandran_40_1, f"{out_dir_40_1}/ramachandran.png")

fig_dssp_40_1 = plot_dssp_fractions(frac_md_40_1, frac_gen_40_1)
save_figure(fig_dssp_40_1, f"{out_dir_40_1}/dssp_fractions.png")

fig_dssp_delta_40_1 =  plot_dssp_delta_helix(delta_h_40_1)
save_figure(fig_dssp_delta_40_1,f"{out_dir_40_1}/dssp_delta.png")

fig_contact_ref_40_1 = plot_contact_map(cm_ref_40_1, title="Contact Map REF")
fig_contact_gen_40_1 = plot_contact_map(cm_gen_40_1, title="Contact Map GEN")
save_figure(fig_contact_ref_40_1,f"{out_dir_40_1}/contact_map_ref.png")
save_figure(fig_contact_gen_40_1,f"{out_dir_40_1}/contact_map_gen.png")

fig_pca_40_1 = plot_pca(X_ref_pca_40_1, X_gen_pca_40_1)
save_figure(fig_pca_40_1, f"{out_dir_40_1}/pca.png")

# %% [markdown]
# #### Fraction 60 (Train %60 Test %40)

# %%
gen_traj_60_1 = "../pep_free/pep_free_rep_1/fraction_60/generated_frac_60.xtc"
ref_traj_60_1 = "../../data/palantir_data/pep_free/pep_free_rep_1_backbone.xtc"
pdb = "../../data/palantir_data/pep_free/backbone.pdb"

gen_traj_60_1, ref_traj_60_1 = data_preprocessing(
    gen_traj = gen_traj_60_1,
    ref_traj = ref_traj_60_1,
    backbone_pdb = pdb
)

# RMSD
rmsd_gen_60_1, rmsd_ref_60_1 = rmsd_internal(gen_traj_60_1, ref_traj_60_1)

# RMSF
res_ids_60_1, rmsf_ref_60_1, rmsf_gen_60_1 = rmsf_md_vs_gen(gen_traj_60_1, ref_traj_60_1)

# Rg
rg_gen_60_1, rg_ref_60_1 = radius_of_gyration(gen_traj_60_1, ref_traj_60_1)

# Ramachandran
phi_r_60_1, psi_r_60_1, phi_g_60_1, psi_g_60_1 = compute_phi_psi(gen_traj_60_1, ref_traj_60_1)

# DSSP
dssp_ref_60_1, dssp_gen_60_1, frac_md_60_1, frac_gen_60_1, delta_h_60_1 = dssp_analysis(ref_traj_60_1, gen_traj_60_1)

# Contact map
cm_ref_60_1 = compute_contact_map(ref_traj_60_1)
cm_gen_60_1 = compute_contact_map(gen_traj_60_1)

# PCA
X_ref_pca_60_1, X_gen_pca_60_1 = pca(gen_traj_60_1, ref_traj_60_1)

# %%
out_dir_60_1 = '../results/pep_free_1/fraction_60'

fig_rmsd_60_1 = plot_rmsd(rmsd_ref_60_1, rmsd_gen_60_1)
save_figure(fig_rmsd_60_1, f'{out_dir_60_1}/rmsd.png')

save_array_txt(rmsd_ref_60_1,f'{out_dir_60_1}/rmsd_ref.txt')
save_array_txt(rmsd_gen_60_1, f'{out_dir_60_1}/rmsd_gen.txt')


fig_rmsf_60_1 = plot_rmsf(res_ids_60_1, rmsf_ref_60_1, rmsf_gen_60_1)
save_figure(fig_rmsf_60_1,f"{out_dir_60_1}/rmsf.png")

save_array_txt(rmsf_ref_60_1,f"{out_dir_60_1}/rmsf_ref.txt")
save_array_txt(rmsf_gen_60_1,f"{out_dir_60_1}/rmsf_gen.txt")
save_array_txt(res_ids_60_1, f"{out_dir_60_1}/res__ids.txt")

fig_rg_60_1 = plot_rg(rg_ref_60_1, rg_gen_60_1)
save_figure(fig_rg_60_1 , f"{out_dir_60_1}/rg.png")

save_array_txt(rg_ref_60_1, f"{out_dir_60_1}/rg_ref.txt")
save_array_txt(rg_gen_60_1, f"{out_dir_60_1}/rg_gen.txt")

fig_ramachandran_60_1 = plot_ramachandran(phi_r_60_1, psi_r_60_1, phi_g_60_1, psi_g_60_1)
save_figure(fig_ramachandran_60_1, f"{out_dir_60_1}/ramachandran.png")

fig_dssp_60_1 = plot_dssp_fractions(frac_md_60_1, frac_gen_60_1)
save_figure(fig_dssp_60_1, f"{out_dir_60_1}/dssp_fractions.png")

fig_dssp_delta_60_1 =  plot_dssp_delta_helix(delta_h_60_1)
save_figure(fig_dssp_delta_60_1, f"{out_dir_60_1}/dssp_delta.png")

fig_contact_ref_60_1 = plot_contact_map(cm_ref_60_1, title="Contact Map REF")
fig_contact_gen_60_1 = plot_contact_map(cm_gen_60_1, title="Contact Map GEN")
save_figure(fig_contact_ref_60_1, f"{out_dir_60_1}/contact_map_ref.png")
save_figure(fig_contact_gen_60_1, f"{out_dir_60_1}/contact_map_gen.png")

fig_pca_60_1 = plot_pca(X_ref_pca_60_1, X_gen_pca_60_1)
save_figure(fig_pca_60_1, f"{out_dir_60_1}/pca.png")

# %% [markdown]
# # Pep Free Replica 2

# %% [markdown]
# #### Fraction 20 (Train %20 Test %80)

# %%
gen_traj_20_2 = "../pep_free/pep_free_rep_2/fraction_20/generated_frac_20.xtc"
ref_traj_20_2 = "../../data/palantir_data/pep_free/pep_free_rep_2_backbone.xtc"
pdb = "../../data/palantir_data/pep_free/backbone.pdb"


gen_traj_20_2, ref_traj_20_2 = data_preprocessing(
    gen_traj = gen_traj_20_2,
    ref_traj = ref_traj_20_2,
    backbone_pdb = pdb
)

# RMSD
rmsd_gen_20_2, rmsd_ref_20_2 = rmsd_internal(gen_traj_20_2, ref_traj_20_2)

# RMSF
res_ids_20_2, rmsf_ref_20_2, rmsf_gen_20_2 = rmsf_md_vs_gen(gen_traj_20_2, ref_traj_20_2)

# Rg
rg_gen_20_2, rg_ref_20_2 = radius_of_gyration(gen_traj_20_2, ref_traj_20_2)

# Ramachandran
phi_r_20_2, psi_r_20_2, phi_g_20_2, psi_g_20_2 = compute_phi_psi(gen_traj_20_2, ref_traj_20_2)

# DSSP
dssp_ref_20_2, dssp_gen_20_2, frac_md_20_2, frac_gen_20_2, delta_h_20_2 = dssp_analysis(ref_traj_20_2, gen_traj_20_2)

# Contact map
cm_ref_20_2 = compute_contact_map(ref_traj_20_2)
cm_gen_20_2 = compute_contact_map(gen_traj_20_2)

# PCA
X_ref_pca_20_2, X_gen_pca_20_2 = pca(gen_traj_20_2, ref_traj_20_2)

# %%
out_dir_20_2 = '../results/pep_free_2/fraction_20'

fig_rmsd_20_2 = plot_rmsd(rmsd_ref_20_2, rmsd_gen_20_2)
save_figure(fig_rmsd_20_2, f"{out_dir_20_2}/rmsd.png")

save_array_txt(rmsd_ref_20_2, f"{out_dir_20_2}/rmsd_ref.txt")
save_array_txt(rmsd_gen_20_2, f"{out_dir_20_2}/rmsd_gen.txt")


fig_rmsf_20_2 = plot_rmsf(res_ids_20_2, rmsf_ref_20_2, rmsf_gen_20_2)
save_figure(fig_rmsf_20_2, f"{out_dir_20_2}/rmsf.png")

save_array_txt(rmsf_ref_20_2, f"{out_dir_20_2}/rmsf_ref.txt")
save_array_txt(rmsf_gen_20_2, f"{out_dir_20_2}/rmsf_gen.txt")
save_array_txt(res_ids_20_2, f"{out_dir_20_2}/res__ids.txt")

fig_rg_20_2 = plot_rg(rg_ref_20_2, rg_gen_20_2)
save_figure(fig_rg_20_2 , f"{out_dir_20_2}/rg.png")

save_array_txt(rg_ref_20_2, f"{out_dir_20_2}/rg_ref.txt")
save_array_txt(rg_gen_20_2, f"{out_dir_20_2}/rg_gen.txt")

fig_ramachandran_20_2 = plot_ramachandran(phi_r_20_2, psi_r_20_2, phi_g_20_2, psi_g_20_2)
save_figure(fig_ramachandran_20_2, f"{out_dir_20_2}/ramachandran.png")

fig_dssp_20_2 = plot_dssp_fractions(frac_md_20_2, frac_gen_20_2)
save_figure(fig_dssp_20_2, f"{out_dir_20_2}/dssp_fractions.png")

fig_dssp_delta_20_2 =  plot_dssp_delta_helix(delta_h_20_2)
save_figure(fig_dssp_delta_20_2, f"{out_dir_20_2}/dssp_delta.png")

fig_contact_ref_20_2 = plot_contact_map(cm_ref_20_2, title="Contact Map REF")
fig_contact_gen_20_2 = plot_contact_map(cm_gen_20_2, title="Contact Map GEN")
save_figure(fig_contact_ref_20_2, f"{out_dir_20_2}/contact_map_ref.png")
save_figure(fig_contact_gen_20_2, f"{out_dir_20_2}/contact_map_gen.png")


fig_pca_20_2 = plot_pca(X_ref_pca_20_2, X_gen_pca_20_2)
save_figure(fig_pca_20_2, f"{out_dir_20_2}/pca.png")

# %% [markdown]
# #### Fraction 40 (Train %40 Test %60)

# %%
gen_traj_40_2 = "../pep_free/pep_free_rep_2/fraction_40/generated_frac_40.xtc"
ref_traj_40_2 = "../../data/palantir_data/pep_free/pep_free_rep_2_backbone.xtc"
pdb = "../../data/palantir_data/pep_free/backbone.pdb"



gen_traj_40_2, ref_traj_40_2 = data_preprocessing(
    gen_traj = gen_traj_40_2,
    ref_traj = ref_traj_40_2,
    backbone_pdb = pdb
)

# RMSD
rmsd_gen_40_2, rmsd_ref_40_2= rmsd_internal(gen_traj_40_2, ref_traj_40_2)

# RMSF
res_ids_40_2, rmsf_ref_40_2, rmsf_gen_40_2 = rmsf_md_vs_gen(gen_traj_40_2, ref_traj_40_2)

# Rg
rg_gen_40_2, rg_ref_40_2 = radius_of_gyration(gen_traj_40_2, ref_traj_40_2)

# Ramachandran
phi_r_40_2, psi_r_40_2, phi_g_40_2, psi_g_40_2 = compute_phi_psi(gen_traj_40_2, ref_traj_40_2)

# DSSP
dssp_ref_40_2, dssp_gen_40_2, frac_md_40_2, frac_gen_40_2, delta_h_40_2 = dssp_analysis(ref_traj_40_2, gen_traj_40_2)

# Contact map
cm_ref_40_2 = compute_contact_map(ref_traj_40_2)
cm_gen_40_2 = compute_contact_map(gen_traj_40_2)

# PCA
X_ref_pca_40_2, X_gen_pca_40_2 = pca(gen_traj_40_2, ref_traj_40_2)

# %%
out_dir_40_2 = '../results/pep_free_2/fraction_40'


fig_rmsd_40_2 = plot_rmsd(rmsd_ref_40_2 , rmsd_gen_40_2)
save_figure(fig_rmsd_40_2, f"{out_dir_40_2}/rmsd.png")

save_array_txt(rmsd_ref_40_2,f"{out_dir_40_2}/rmsd_ref.txt")
save_array_txt(rmsd_gen_40_2,f"{out_dir_40_2}/rmsd_gen.txt")


fig_rmsf_40_2 = plot_rmsf(res_ids_40_2, rmsf_ref_40_2, rmsf_gen_40_2)
save_figure(fig_rmsf_40_2,f"{out_dir_40_2}/rmsf.png")

save_array_txt(rmsf_ref_40_2,f"{out_dir_40_2}/rmsf_ref.txt")
save_array_txt(rmsf_gen_40_2,f"{out_dir_40_2}/rmsf_gen.txt")
save_array_txt(res_ids_40_2,f"{out_dir_40_2}/res__ids.txt")

fig_rg_40_2 = plot_rg(rg_ref_40_2, rg_gen_40_2)
save_figure(fig_rg_40_2 , f"{out_dir_40_2}/rg.png")

save_array_txt(rg_ref_40_2, f"{out_dir_40_2}/rg_ref.txt")
save_array_txt(rg_gen_40_2, f"{out_dir_40_2}/rg_gen.txt")

fig_ramachandran_40_2 = plot_ramachandran(phi_r_40_2, psi_r_40_2, phi_g_40_2, psi_g_40_2,)
save_figure(fig_ramachandran_40_2, f"{out_dir_40_2}/ramachandran.png")

fig_dssp_40_2 = plot_dssp_fractions(frac_md_40_2, frac_gen_40_2)
save_figure(fig_dssp_40_2, f"{out_dir_40_2}/dssp_fractions.png")

fig_dssp_delta_40_2 =  plot_dssp_delta_helix(delta_h_40_2)
save_figure(fig_dssp_delta_40_2,f"{out_dir_40_2}/dssp_delta.png")

fig_contact_ref_40_2 = plot_contact_map(cm_ref_40_2, title="Contact Map REF")
fig_contact_gen_40_2 = plot_contact_map(cm_gen_40_2, title="Contact Map GEN")
save_figure(fig_contact_ref_40_2,f"{out_dir_40_2}/contact_map_ref.png")
save_figure(fig_contact_gen_40_2,f"{out_dir_40_2}/contact_map_gen.png")

fig_pca_40_2 = plot_pca(X_ref_pca_40_2, X_gen_pca_40_2)
save_figure(fig_pca_40_2, f"{out_dir_40_2}/pca.png")

# %% [markdown]
# #### Fraction 60 (Train %60 Test %40)

# %%
gen_traj_60_2 = "../pep_free/pep_free_rep_2/fraction_60/generated_frac_60.xtc"
ref_traj_60_2 = "../../data/palantir_data/pep_free/pep_free_rep_2_backbone.xtc"
pdb = "../../data/palantir_data/pep_free/backbone.pdb"


gen_traj_60_2, ref_traj_60_2 = data_preprocessing(
    gen_traj = gen_traj_60_2,
    ref_traj = ref_traj_60_2,
    backbone_pdb = pdb
)

# RMSD
rmsd_gen_60_2, rmsd_ref_60_2 = rmsd_internal(gen_traj_60_2, ref_traj_60_2)

# RMSF
res_ids_60_2, rmsf_ref_60_2, rmsf_gen_60_2 = rmsf_md_vs_gen(gen_traj_60_2, ref_traj_60_2)

# Rg
rg_gen_60_2, rg_ref_60_2 = radius_of_gyration(gen_traj_60_2, ref_traj_60_2)

# Ramachandran
phi_r_60_2, psi_r_60_2, phi_g_60_2, psi_g_60_2 = compute_phi_psi(gen_traj_60_2, ref_traj_60_2)

# DSSP
dssp_ref_60_2, dssp_gen_60_2, frac_md_60_2, frac_gen_60_2, delta_h_60_2 = dssp_analysis(ref_traj_60_2, gen_traj_60_2)

# Contact map
cm_ref_60_2 = compute_contact_map(ref_traj_60_2)
cm_gen_60_2 = compute_contact_map(gen_traj_60_2)

# PCA
X_ref_pca_60_2, X_gen_pca_60_2 = pca(gen_traj_60_2, ref_traj_60_2)

# %%
out_dir_60_2 = '../results/pep_free_2/fraction_60'

fig_rmsd_60_2 = plot_rmsd(rmsd_ref_60_2, rmsd_gen_60_2)
save_figure(fig_rmsd_60_2, f'{out_dir_60_2}/rmsd.png')

save_array_txt(rmsd_ref_60_2,f'{out_dir_60_2}/rmsd_ref.txt')
save_array_txt(rmsd_gen_60_2, f'{out_dir_60_2}/rmsd_gen.txt')


fig_rmsf_60_2 = plot_rmsf(res_ids_60_2, rmsf_ref_60_2, rmsf_gen_60_2)
save_figure(fig_rmsf_60_2,f"{out_dir_60_2}/rmsf.png")

save_array_txt(rmsf_ref_60_2, f"{out_dir_60_2}/rmsf_ref.txt")
save_array_txt(rmsf_gen_60_2, f"{out_dir_60_2}/rmsf_gen.txt")
save_array_txt(res_ids_60_2, f"{out_dir_60_2}/res__ids.txt")

fig_rg_60_2 = plot_rg(rg_ref_60_2, rg_gen_60_2)
save_figure(fig_rg_60_2 , f"{out_dir_60_2}/rg.png")

save_array_txt(rg_ref_60_2, f"{out_dir_60_2}/rg_ref.txt")
save_array_txt(rg_gen_60_2, f"{out_dir_60_2}/rg_gen.txt")

fig_ramachandran_60_2 = plot_ramachandran(phi_r_60_2, psi_r_60_2, phi_g_60_2, psi_g_60_2)
save_figure(fig_ramachandran_60_2, f"{out_dir_60_2}/ramachandran.png")

fig_dssp_60_2 = plot_dssp_fractions(frac_md_60_2, frac_gen_60_2)
save_figure(fig_dssp_60_2, f"{out_dir_60_2}/dssp_fractions.png")

fig_dssp_delta_60_2 =  plot_dssp_delta_helix(delta_h_60_2)
save_figure(fig_dssp_delta_60_2, f"{out_dir_60_2}/dssp_delta.png")

fig_contact_ref_60_2 = plot_contact_map(cm_ref_60_2, title="Contact Map REF")
fig_contact_gen_60_2 = plot_contact_map(cm_gen_60_2, title="Contact Map GEN")
save_figure(fig_contact_ref_60_2, f"{out_dir_60_2}/contact_map_ref.png")
save_figure(fig_contact_gen_60_2, f"{out_dir_60_2}/contact_map_gen.png")
fig_pca_60_2 = plot_pca(X_ref_pca_60_2, X_gen_pca_60_2)
save_figure(fig_pca_60_2, f"{out_dir_60_2}/pca.png")
