# %%
from VAE import *
# Out:
# 2025-11-21 14:01:12.577090: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-21 14:01:12.577157: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-21 14:01:12.629063: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-21 14:01:12.712287: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # 5C0F
# - %10 Train

# %%
x_train_5C0F, x_test_5C0F , x_train_orig_5C0F ,x_test_orig_5C0F , scaler_5C0F = preprocess_pipeline(
    dcd_file="proteins/5C0F/5C0F_replica_0.dcd",
    pdb_file="proteins/5C0F/5C0F.pdb",
    protein_name="5C0F",
    train_ratio=0.1
)

history_5C0F, sampling_model_5C0F = model_training(32, 300, x_train_5C0F, x_test_5C0F)

reshaped_train_5C0F, reconstruct_train_5C0F, reshaped_test_5C0F, reconstruct_test_5C0F =  reconstruct(x_train_5C0F,x_test_5C0F,sampling_model_5C0F, scaler_5C0F)
# Out:
# dcdplugin) detected standard 32-bit DCD file of native endianness
# dcdplugin) CHARMM format DCD file (also NAMD 2.1 and later)
# > Loaded 1001 frames, 1548 selected atoms.
# > All frames aligned to reference (frame 0).
# > Split into 100 train and 901 test frames.
# > Data saved under 'processed_data/'
# > Data loaded from 'processed_data/'
# > Data normalized to [0, 1].
# > Preprocessing complete.
# 2025-11-21 14:01:26.625379: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-11-21 14:01:27.058535: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# ...

# %%
output_path_5C0F = save_selected_atoms("proteins/5C0F/5C0F.pdb")
dcd_path_5C0F = create_dcd_from_decoded(
    pdb_file="selected_pdb/5C0F_selected.pdb",
    decoded_coords=reshaped_test_5C0F,  # (n_frames, n_atoms, 3)
    output_prefix="5C0F",
    output_dir="generated_files"
)


rmsd_values_5C0F = compute_rmsd(
    reference_pdb=output_path_5C0F,
    dcd_file=dcd_path_5C0F,
    atom_selection="name N or name CA or name C or name O",
    output_txt="generated_files/5C0F_generated_rmsd.txt"
)
# Out:
# > DCD file saved: generated_files/5C0F_generated.dcd
# dcdplugin) detected standard 32-bit DCD file of native endianness
# dcdplugin) CHARMM format DCD file (also NAMD 2.1 and later)
# > RMSD values saved: generated_files/5C0F_generated_rmsd.txt

# %% [markdown]
# - %20 Train

# %%
x_train_5C0F, x_test_5C0F , x_train_orig_5C0F ,x_test_orig_5C0F , scaler_5C0F = preprocess_pipeline(
    dcd_file="proteins/5C0F/5C0F_replica_0.dcd",
    pdb_file="proteins/5C0F/5C0F.pdb",
    protein_name="5C0F_0.2",
    train_ratio=0.2
)

history_5C0F, sampling_model_5C0F = model_training(32, 300, x_train_5C0F, x_test_5C0F)

reshaped_train_5C0F, reconstruct_train_5C0F, reshaped_test_5C0F, reconstruct_test_5C0F =  reconstruct(x_train_5C0F,x_test_5C0F,sampling_model_5C0F, scaler_5C0F)
# Out:
# dcdplugin) detected standard 32-bit DCD file of native endianness
# dcdplugin) CHARMM format DCD file (also NAMD 2.1 and later)
# > Loaded 1001 frames, 1548 selected atoms.
# > All frames aligned to reference (frame 0).
# > Split into 200 train and 801 test frames.
# > Data saved under 'processed_data/'
# > Data loaded from 'processed_data/'
# > Data normalized to [0, 1].
# > Preprocessing complete.
# Epoch 1/300
# 7/7 [==============================] - 4s 107ms/step - loss: 1.0115 - mean_squared_error: 0.0390 - val_loss: 0.9954 - val_mean_squared_error: 0.0642
# Epoch 2/300
# 7/7 [==============================] - 0s 53ms/step - loss: 0.9355 - mean_squared_error: 0.0387 - val_loss: 0.9324 - val_mean_squared_error: 0.0643
# Epoch 3/300
# 7/7 [==============================] - 0s 48ms/step - loss: 0.8653 - mean_squared_error: 0.0381 - val_loss: 0.8630 - val_mean_squared_error: 0.0659
# Epoch 4/300
# ...

# %%
output_path_5C0F = save_selected_atoms("proteins/5C0F/5C0F.pdb")
dcd_path_5C0F = create_dcd_from_decoded(
    pdb_file="selected_pdb/5C0F_selected.pdb",
    decoded_coords=reshaped_test_5C0F,  # (n_frames, n_atoms, 3)
    output_prefix="5C0F_0.2",
    output_dir="generated_files"
)


rmsd_values_5C0F = compute_rmsd(
    reference_pdb=output_path_5C0F,
    dcd_file=dcd_path_5C0F,
    atom_selection="name N or name CA or name C or name O",
    output_txt="generated_files/5C0F_generated_rmsd_0.2.txt"
)
# Out:
# > DCD file saved: generated_files/5C0F_0.2_generated.dcd
# dcdplugin) detected standard 32-bit DCD file of native endianness
# dcdplugin) CHARMM format DCD file (also NAMD 2.1 and later)
# > RMSD values saved: generated_files/5C0F_generated_rmsd_0.2.txt

# %% [markdown]
# - %30 Train

# %%
x_train_5C0F, x_test_5C0F , x_train_orig_5C0F ,x_test_orig_5C0F , scaler_5C0F = preprocess_pipeline(
    dcd_file="proteins/5C0F/5C0F_replica_0.dcd",
    pdb_file="proteins/5C0F/5C0F.pdb",
    protein_name="5C0F_0.3",
    train_ratio=0.3
)

history_5C0F, sampling_model_5C0F = model_training(32, 300, x_train_5C0F, x_test_5C0F)

reshaped_train_5C0F, reconstruct_train_5C0F, reshaped_test_5C0F, reconstruct_test_5C0F =  reconstruct(x_train_5C0F,x_test_5C0F,sampling_model_5C0F, scaler_5C0F)
# Out:
# dcdplugin) detected standard 32-bit DCD file of native endianness
# dcdplugin) CHARMM format DCD file (also NAMD 2.1 and later)
# > Loaded 1001 frames, 1548 selected atoms.
# > All frames aligned to reference (frame 0).
# > Split into 300 train and 701 test frames.
# > Data saved under 'processed_data/'
# > Data loaded from 'processed_data/'
# > Data normalized to [0, 1].
# > Preprocessing complete.
# Epoch 1/300
# 10/10 [==============================] - 3s 81ms/step - loss: 0.9881 - mean_squared_error: 0.0361 - val_loss: 0.9417 - val_mean_squared_error: 0.0589
# Epoch 2/300
# 10/10 [==============================] - 0s 38ms/step - loss: 0.8841 - mean_squared_error: 0.0355 - val_loss: 0.8432 - val_mean_squared_error: 0.0589
# Epoch 3/300
# 10/10 [==============================] - 0s 25ms/step - loss: 0.7889 - mean_squared_error: 0.0343 - val_loss: 0.7547 - val_mean_squared_error: 0.0632
# Epoch 4/300
# ...

# %%
output_path_5C0F = save_selected_atoms("proteins/5C0F/5C0F.pdb")
dcd_path_5C0F = create_dcd_from_decoded(
    pdb_file="selected_pdb/5C0F_selected.pdb",
    decoded_coords=reshaped_test_5C0F,  # (n_frames, n_atoms, 3)
    output_prefix="5C0F_0.3",
    output_dir="generated_files"
)


rmsd_values_5C0F = compute_rmsd(
    reference_pdb=output_path_5C0F,
    dcd_file=dcd_path_5C0F,
    atom_selection="name N or name CA or name C or name O",
    output_txt="generated_files/5C0F_generated_rmsd_0.3.txt"
)
# Out:
# > DCD file saved: generated_files/5C0F_0.3_generated.dcd
# dcdplugin) detected standard 32-bit DCD file of native endianness
# dcdplugin) CHARMM format DCD file (also NAMD 2.1 and later)
# > RMSD values saved: generated_files/5C0F_generated_rmsd_0.3.txt

# %% [markdown]
# - %40 Train

# %%
x_train_5C0F, x_test_5C0F , x_train_orig_5C0F ,x_test_orig_5C0F , scaler_5C0F = preprocess_pipeline(
    dcd_file="proteins/5C0F/5C0F_replica_0.dcd",
    pdb_file="proteins/5C0F/5C0F.pdb",
    protein_name="5C0F_0.4",
    train_ratio=0.4
)

history_5C0F, sampling_model_5C0F = model_training(32, 300, x_train_5C0F, x_test_5C0F)

reshaped_train_5C0F, reconstruct_train_5C0F, reshaped_test_5C0F, reconstruct_test_5C0F =  reconstruct(x_train_5C0F,x_test_5C0F,sampling_model_5C0F, scaler_5C0F)
# Out:
# dcdplugin) detected standard 32-bit DCD file of native endianness
# dcdplugin) CHARMM format DCD file (also NAMD 2.1 and later)
# > Loaded 1001 frames, 1548 selected atoms.
# > All frames aligned to reference (frame 0).
# > Split into 400 train and 601 test frames.
# > Data saved under 'processed_data/'
# > Data loaded from 'processed_data/'
# > Data normalized to [0, 1].
# > Preprocessing complete.
# Epoch 1/300
# 13/13 [==============================] - 3s 56ms/step - loss: 0.9715 - mean_squared_error: 0.0337 - val_loss: 0.9146 - val_mean_squared_error: 0.0597
# Epoch 2/300
# 13/13 [==============================] - 0s 23ms/step - loss: 0.8393 - mean_squared_error: 0.0328 - val_loss: 0.7885 - val_mean_squared_error: 0.0598
# Epoch 3/300
# 13/13 [==============================] - 0s 24ms/step - loss: 0.7228 - mean_squared_error: 0.0313 - val_loss: 0.6808 - val_mean_squared_error: 0.0639
# Epoch 4/300
# ...

# %%
output_path_5C0F = save_selected_atoms("proteins/5C0F/5C0F.pdb")
dcd_path_5C0F = create_dcd_from_decoded(
    pdb_file="selected_pdb/5C0F_selected.pdb",
    decoded_coords=reshaped_test_5C0F,  
    output_prefix="5C0F_0.4",
    output_dir="generated_files"
)


rmsd_values_5C0F = compute_rmsd(
    reference_pdb=output_path_5C0F,
    dcd_file=dcd_path_5C0F,
    atom_selection="name N or name CA or name C or name O",
    output_txt="generated_files/5C0F_generated_rmsd_0.4.txt"
)
# Out:
# > DCD file saved: generated_files/5C0F_0.4_generated.dcd
# dcdplugin) detected standard 32-bit DCD file of native endianness
# dcdplugin) CHARMM format DCD file (also NAMD 2.1 and later)
# > RMSD values saved: generated_files/5C0F_generated_rmsd_0.4.txt

# %% [markdown]
# - %50 Train

# %%
x_train_5C0F, x_test_5C0F , x_train_orig_5C0F ,x_test_orig_5C0F , scaler_5C0F = preprocess_pipeline(
    dcd_file="proteins/5C0F/5C0F_replica_0.dcd",
    pdb_file="proteins/5C0F/5C0F.pdb",
    protein_name="5C0F_0.5",
    train_ratio=0.5
)

history_5C0F, sampling_model_5C0F = model_training(32, 300, x_train_5C0F, x_test_5C0F)

reshaped_train_5C0F, reconstruct_train_5C0F, reshaped_test_5C0F, reconstruct_test_5C0F =  reconstruct(x_train_5C0F,x_test_5C0F,sampling_model_5C0F, scaler_5C0F)
# Out:
# dcdplugin) detected standard 32-bit DCD file of native endianness
# dcdplugin) CHARMM format DCD file (also NAMD 2.1 and later)
# > Loaded 1001 frames, 1548 selected atoms.
# > All frames aligned to reference (frame 0).
# > Split into 500 train and 501 test frames.
# > Data saved under 'processed_data/'
# > Data loaded from 'processed_data/'
# > Data normalized to [0, 1].
# > Preprocessing complete.
# Epoch 1/300
# 16/16 [==============================] - 4s 54ms/step - loss: 0.9574 - mean_squared_error: 0.0322 - val_loss: 0.8996 - val_mean_squared_error: 0.0633
# Epoch 2/300
# 16/16 [==============================] - 0s 27ms/step - loss: 0.7992 - mean_squared_error: 0.0306 - val_loss: 0.7593 - val_mean_squared_error: 0.0896
# Epoch 3/300
# 16/16 [==============================] - 0s 28ms/step - loss: 0.6643 - mean_squared_error: 0.0291 - val_loss: 0.6276 - val_mean_squared_error: 0.0805
# Epoch 4/300
# ...

# %%
output_path_5C0F = save_selected_atoms("proteins/5C0F/5C0F.pdb")
dcd_path_5C0F = create_dcd_from_decoded(
    pdb_file="selected_pdb/5C0F_selected.pdb",
    decoded_coords=reshaped_test_5C0F,
    output_prefix="5C0F_0.5",
    output_dir="generated_files"
)


rmsd_values_5C0F = compute_rmsd(
    reference_pdb=output_path_5C0F,
    dcd_file=dcd_path_5C0F,
    atom_selection="name N or name CA or name C or name O",
    output_txt="generated_files/5C0F_generated_rmsd_0.5.txt"
)
# Out:
# > DCD file saved: generated_files/5C0F_0.5_generated.dcd
# dcdplugin) detected standard 32-bit DCD file of native endianness
# dcdplugin) CHARMM format DCD file (also NAMD 2.1 and later)
# > RMSD values saved: generated_files/5C0F_generated_rmsd_0.5.txt

# %% [markdown]
# # RMSD

# %%
def compute_rmsd_per_frame(pdb_file,
                           dcd_file,
                           atom_selection="name N or name CA or name C or name O", 
                           align=True,
                           ref_frame=0,
                           plot=True):
 

    
    traj = md.load_dcd(dcd_file, top=pdb_file)  

    
    atom_indices = traj.topology.select(atom_selection)
    ref = traj[ref_frame]

   
    if align:
        traj_super = traj.superpose(ref, atom_indices=atom_indices)  
    else:
        traj_super = traj  

    rmsd_vals_nm = md.rmsd(traj_super, ref, atom_indices=atom_indices)

    if plot:
        plt.figure(figsize=(8,3.5))
        plt.plot(rmsd_vals_nm , lw=1.5)  
        plt.xlabel("Frame")
        plt.ylabel("RMSD(nm)")
        plt.title("RMSD 5C0F MD Simulation")

# %%
dcd_file="proteins/5C0F/5C0F_replica_0.dcd"
pdb_file="proteins/5C0F/5C0F.pdb"

compute_rmsd_per_frame(pdb_file,
                           dcd_file,
                           atom_selection="name N or name CA or name C or name O", 
                           align=True,
                           ref_frame=0,
                           plot=True)
# Out:
# dcdplugin) detected standard 32-bit DCD file of native endianness
# dcdplugin) CHARMM format DCD file (also NAMD 2.1 and later)

# %%
from scipy.ndimage import uniform_filter1d

data_dir = "generated_files"

files = {
    "10%": os.path.join(data_dir, "5C0F_generated_rmsd.txt"),
    "20%": os.path.join(data_dir, "5C0F_generated_rmsd_0.2.txt"),
    "30%": os.path.join(data_dir, "5C0F_generated_rmsd_0.3.txt"),
    "40%": os.path.join(data_dir, "5C0F_generated_rmsd_0.4.txt"),
    "50%": os.path.join(data_dir, "5C0F_generated_rmsd_0.5.txt"),
}

plt.figure(figsize=(10, 6))
window = 10  

for label, file_path in files.items():
    if os.path.exists(file_path):
        rmsd_values = np.loadtxt(file_path)
    
        smooth_rmsd = uniform_filter1d(rmsd_values, size=window)
        plt.plot(smooth_rmsd, lw=2, label=f"Train {label}", alpha=0.9)


plt.title("RMSD Values - Different Train Ratio", fontsize=14)
plt.xlabel("Frame Index", fontsize=12)
plt.ylabel("RMSD (nm)", fontsize=12)
plt.legend(title="Train Set", fontsize=10)
plt.grid(True, linestyle="--", alpha=0.4)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
data_dir = "generated_files"


files = {
    "10%": os.path.join(data_dir, "5C0F_generated_rmsd.txt"),
    "20%": os.path.join(data_dir, "5C0F_generated_rmsd_0.2.txt"),
    "30%": os.path.join(data_dir, "5C0F_generated_rmsd_0.3.txt"),
    "40%": os.path.join(data_dir, "5C0F_generated_rmsd_0.4.txt"),
    "50%": os.path.join(data_dir, "5C0F_generated_rmsd_0.5.txt"),
}


plt.style.use("seaborn-v0_8-whitegrid")
plt.figure(figsize=(10, 6))
colors = sns.color_palette("viridis", n_colors=len(files))
window = 15  

for i, (label, file_path) in enumerate(files.items()):
    if os.path.exists(file_path):
        rmsd = np.loadtxt(file_path)
   
        smooth = uniform_filter1d(rmsd, size=window)

        x = np.linspace(0, 1, len(smooth))

        plt.plot(x, smooth, lw=2, color=colors[i], label=f"Train {label}")


plt.title("RMSD 5C0F", fontsize=14)
plt.xlabel("Normalized Trajectory Progress", fontsize=12)
plt.ylabel("RMSD (nm)", fontsize=12)
plt.legend(title="Train Set", fontsize=10)
plt.grid(True, linestyle="--", alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# # BOX Plot

# %%
import seaborn as sns
import pandas as pd

def split_dcd_by_percentage(dcd_file, pdb_file, output_dir="subset_dcds", percentages=[10, 20, 30, 40, 50]):

    os.makedirs(output_dir, exist_ok=True)

   
    traj = md.load_dcd(dcd_file, top=pdb_file)
    total_frames = traj.n_frames
    print(f"Total Frames: {total_frames}")

   
    for p in percentages:
        subset_frames = int(total_frames * (p / 100.0))
        subset_traj = traj[:subset_frames]  
        output_path = os.path.join(output_dir, f"{p}percent_{os.path.basename(dcd_file)}")
        subset_traj.save_dcd(output_path)
        print(f"{p}% {subset_frames} frame -> {output_path}")


dcd_file="proteins/5C0F/5C0F_replica_0.dcd"
pdb_file="proteins/5C0F/5C0F.pdb"

split_dcd_by_percentage(dcd_file, pdb_file)



def rmsd_distribution_for_files(pdb_file, dcd_files, atom_selection="name CA"):
    ref = md.load_pdb(pdb_file)
    atom_indices = ref.topology.select(atom_selection)
    ref = ref.atom_slice(atom_indices)

    rmsd_dict = {}
    for f in dcd_files:
        traj = md.load_dcd(f, top=pdb_file)
        traj = traj.atom_slice(atom_indices)
        rmsd = md.rmsd(traj, ref)
        rmsd_dict[os.path.basename(f)] = rmsd
    return rmsd_dict



pdb_file = "selected_pdb/5C0F_selected.pdb"

vae_files = {
    "10%": "generated_files/5C0F_generated.dcd",
    "20%": "generated_files/5C0F_0.2_generated.dcd",
    "30%": "generated_files/5C0F_0.3_generated.dcd",
    "40%": "generated_files/5C0F_0.4_generated.dcd",
    "50%": "generated_files/5C0F_0.5_generated.dcd",
}
pdb = "proteins/5C0F/5C0F.pdb"
md_files = {
    "10%": "subset_dcds/10percent_5C0F_replica_0.dcd",
    "20%": "subset_dcds/20percent_5C0F_replica_0.dcd",
    "30%": "subset_dcds/30percent_5C0F_replica_0.dcd",
    "40%": "subset_dcds/40percent_5C0F_replica_0.dcd",
    "50%": "subset_dcds/50percent_5C0F_replica_0.dcd",
}


vae_rmsd = rmsd_distribution_for_files(pdb_file, list(vae_files.values()), atom_selection="name CA")
md_rmsd  = rmsd_distribution_for_files(pdb, list(md_files.values()),  atom_selection="name CA")


df_list = []

for label, path in vae_files.items():
    fname = os.path.basename(path)
    rmsd = vae_rmsd[fname]
    df_list.append(pd.DataFrame({"percentage": label, "rmsd": rmsd, "source": "VAE"}))

for label, path in md_files.items():
    fname = os.path.basename(path)
    rmsd = md_rmsd[fname]
    df_list.append(pd.DataFrame({"percentage": label, "rmsd": rmsd, "source": "MD"}))

df = pd.concat(df_list, ignore_index=True)

plt.figure(figsize=(8,6))
sns.boxplot(x="percentage", y="rmsd", hue="source", data=df,showfliers=False,
            palette=["#4C72B0", "#55A868"], width=0.6)


plt.ylabel("RMSD (Å)")
plt.title("RMSD Values - MD vs VAE (5C0F)")
plt.legend(title="", loc="upper right")
plt.tight_layout()
plt.show()
# Out:
# dcdplugin) detected standard 32-bit DCD file of native endianness
# dcdplugin) CHARMM format DCD file (also NAMD 2.1 and later)
# Total Frames: 1001
# 10% 100 frame -> subset_dcds/10percent_5C0F_replica_0.dcd
# 20% 200 frame -> subset_dcds/20percent_5C0F_replica_0.dcd
# 30% 300 frame -> subset_dcds/30percent_5C0F_replica_0.dcd
# 40% 400 frame -> subset_dcds/40percent_5C0F_replica_0.dcd
# 50% 500 frame -> subset_dcds/50percent_5C0F_replica_0.dcd
# dcdplugin) detected standard 32-bit DCD file of native endianness
# dcdplugin) CHARMM format DCD file (also NAMD 2.1 and later)
# dcdplugin) detected standard 32-bit DCD file of native endianness
# dcdplugin) CHARMM format DCD file (also NAMD 2.1 and later)
# dcdplugin) detected standard 32-bit DCD file of native endianness
# dcdplugin) CHARMM format DCD file (also NAMD 2.1 and later)
# dcdplugin) detected standard 32-bit DCD file of native endianness
# dcdplugin) CHARMM format DCD file (also NAMD 2.1 and later)
# ...

# %% [markdown]
# # RMSF

# %%
traj = md.load_dcd("proteins/5C0F/5C0F_replica_0.dcd", top="proteins/5C0F/5C0F.pdb")
atoms = traj.topology.select('name CA')  
traj_atom = traj.atom_slice(atoms)


ref = md.load_pdb("proteins/5C0F/5C0F.pdb").atom_slice(atoms)
traj_atom.superpose(ref)


positions = traj_atom.xyz 
avg_positions = positions.mean(axis=0)
rmsf = np.sqrt(((positions - avg_positions)**2).sum(axis=2).mean(axis=0))


plt.figure(figsize=(10,4))
plt.plot(range(1, len(rmsf)+1), rmsf, lw=2)
plt.xlabel('CA Atoms')
plt.ylabel('RMSF (nm)')
plt.title('RMSF 5C0F (MD Simulation)')
plt.grid(True)
plt.show()
# Out:
# dcdplugin) detected standard 32-bit DCD file of native endianness
# dcdplugin) CHARMM format DCD file (also NAMD 2.1 and later)

# %%
data_dir = "generated_files"


models = {
    "10%": ("5C0F_selected.pdb", "5C0F_generated.dcd"),
    "20%": ("5C0F_selected.pdb", "5C0F_0.2_generated.dcd"),
    "30%": ("5C0F_selected.pdb", "5C0F_0.3_generated.dcd"),
    "40%": ("5C0F_selected.pdb", "5C0F_0.4_generated.dcd"),
    "50%": ("5C0F_selected.pdb", "5C0F_0.5_generated.dcd")
}

plt.figure(figsize=(12,5))


pdb_file = "selected_pdb/5C0F_selected.pdb"
for label, (pdb_file, dcd_file) in models.items():
    pdb_path = os.path.join("selected_pdb", pdb_file)
    dcd_path = os.path.join(data_dir, dcd_file)
    
    
    traj = md.load_dcd(dcd_path, top=pdb_path)
    atoms = traj.topology.select('name CA')
    traj_atom = traj.atom_slice(atoms)
    
   
    ref = md.load_pdb(pdb_path).atom_slice(atoms)
    traj_atom.superpose(ref)
    
    positions = traj_atom.xyz
    avg_positions = positions.mean(axis=0)
    rmsf = np.sqrt(((positions - avg_positions)**2).sum(axis=2).mean(axis=0))
    
    plt.plot(range(1, len(rmsf)+1), rmsf, lw=2, label=label)

plt.xlabel("CA Atoms")
plt.ylabel("RMSF (nm)")
plt.title("RMSF Values 5C0F")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# dcdplugin) detected standard 32-bit DCD file of native endianness
# dcdplugin) CHARMM format DCD file (also NAMD 2.1 and later)
# dcdplugin) detected standard 32-bit DCD file of native endianness
# dcdplugin) CHARMM format DCD file (also NAMD 2.1 and later)
# dcdplugin) detected standard 32-bit DCD file of native endianness
# dcdplugin) CHARMM format DCD file (also NAMD 2.1 and later)
# dcdplugin) detected standard 32-bit DCD file of native endianness
# dcdplugin) CHARMM format DCD file (also NAMD 2.1 and later)
# dcdplugin) detected standard 32-bit DCD file of native endianness
# dcdplugin) CHARMM format DCD file (also NAMD 2.1 and later)
